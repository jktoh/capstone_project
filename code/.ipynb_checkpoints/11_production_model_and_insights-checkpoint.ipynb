# %% [markdown]
# # Production Model And Insights
# ---

# %% [markdown]
# ## Import Libraries And Modules

# %%
# Basic libraries
import pandas as pd

# Plotting libraries
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ---

# %% [markdown]
# ## Load Data

# %% [markdown]
# Load `preprocessed.csv`, `predict.csv` and `feature_importance.csv` from `data` folder into a pandas DataFrame.

# %%
preprocessed = pd.read_csv('../data/preprocessed.csv')
predict = pd.read_csv('../data/predict.csv')
feature_importance = pd.read_csv('../data/feature_importance.csv')

# %% [markdown]
# ---

# %% [markdown]
# ## Plotting And Interpreting Best Model

# %%
feature_importance.iloc[:50].plot.barh(
    x='Features', 
    figsize=(20, 15)
);

# %%
preprocessed.groupby('cap')[feature_importance.iloc[:7]['Features'].values].describe().T
# Out:
# cap                                                                  0  \
# Common Stock Value                                 count  1.918000e+03
#                                                    mean   4.004255e+08
#                                                    std    1.479519e+09
#                                                    min    0.000000e+00
#                                                    25%    8.650000e+04
#                                                    50%    3.000000e+06
#                                                    75%    6.214850e+07
#                                                    max    1.911600e+10
# Goodwill                                           count  1.918000e+03
#                                                    mean   4.972557e+09
#                                                    std    9.094506e+09
#                                                    min    0.000000e+00
#                                                    25%    4.110000e+08
#                                                    50%    1.722600e+09
#                                                    75%    5.362500e+09
#                                                    max    8.396800e+10
# Share Based Compensation                           count  1.918000e+03
#                                                    mean   1.628023e+08
#                                                    std    5.950160e+08
#                                                    min   -8.900000e+07
#                                                    25%    1.820000e+07
#                                                    50%    4.911600e+07
#                                                    75%    1.190000e+08
#                                                    max    9.353000e+09
# Weighted Average Number Of Shares Outstanding B... count  1.918000e+03
#                                                    mean   5.615299e+08
#                                                    std    9.977096e+08
#                                                    min    0.000000e+00
#                                                    25%    1.356865e+08
#                                                    50%    2.847160e+08
#                                                    75%    5.369499e+08
#                                                    max    1.073116e+10
# Retained Earnings Accumulated Deficit              count  1.918000e+03
#                                                    mean   9.875202e+09
#                                                    std    2.213760e+10
#                                                    min   -2.284100e+10
#                                                    25%    9.859000e+08
#                                                    50%    3.424728e+09
#                                                    75%    9.540400e+09
#                                                    max    1.849870e+11
# Stockholders Equity                                count  1.918000e+03
#                                                    mean   1.192059e+10
#                                                    std    2.850137e+10
#                                                    min   -1.324400e+10
#                                                    25%    1.619828e+09
#                                                    50%    4.529000e+09
#                                                    75%    1.021590e+10
#                                                    max    2.671460e+11
# Assets                                             count  1.918000e+03
#                                                    mean   6.093557e+10
#                                                    std    2.232296e+11
#                                                    min    0.000000e+00
#                                                    25%    6.797430e+09
#                                                    50%    1.675090e+10
#                                                    75%    3.994975e+10
#                                                    max    2.572274e+12
#
# cap                                                                  1  \
# Common Stock Value                                 count  1.265000e+03
#                                                    mean   7.633949e+07
#                                                    std    3.033734e+08
#                                                    min    0.000000e+00
#                                                    25%    2.000000e+05
#                                                    50%    1.000000e+06
#                                                    75%    1.762500e+07
#                                                    max    3.520591e+09
# Goodwill                                           count  1.265000e+03
#                                                    mean   5.514275e+08
#                                                    std    7.409837e+08
#                                                    min    0.000000e+00
#                                                    25%    1.268600e+07
#                                                    50%    2.768980e+08
#                                                    75%    7.864000e+08
#                                                    max    7.018000e+09
# Share Based Compensation                           count  1.265000e+03
#                                                    mean   1.831030e+07
#                                                    std    2.179592e+07
#                                                    min   -4.668400e+07
#                                                    25%    6.516000e+06
#                                                    50%    1.372600e+07
#                                                    75%    2.360000e+07
#                                                    max    2.935070e+08
# Weighted Average Number Of Shares Outstanding B... count  1.265000e+03
#                                                    mean   9.067821e+07
#                                                    std    8.221210e+07
#                                                    min    0.000000e+00
#                                                    25%    4.524200e+07
#                                                    50%    6.853500e+07
#                                                    75%    1.099000e+08
#                                                    max    9.090000e+08
# Retained Earnings Accumulated Deficit              count  1.265000e+03
#                                                    mean   7.627290e+08
#                                                    std    1.673992e+09
#                                                    min   -1.747400e+10
#                                                    25%    0.000000e+00
#                                                    50%    6.150000e+08
#                                                    75%    1.372000e+09
#                                                    max    1.111289e+10
# Stockholders Equity                                count  1.265000e+03
#                                                    mean   1.482895e+09
#                                                    std    1.438478e+09
#                                                    min   -2.463200e+09
#                                                    25%    5.400000e+08
#                                                    50%    1.190620e+09
#                                                    75%    2.041894e+09
#                                                    max    1.690300e+10
# Assets                                             count  1.265000e+03
#                                                    mean   6.197932e+09
#                                                    std    8.076934e+09
#                                                    min    0.000000e+00
#                                                    25%    1.932089e+09
#                                                    50%    3.516362e+09
#                                                    75%    6.802838e+09
#                                                    max    6.453524e+10
#
# cap                                                                  2
# Common Stock Value                                 count  1.786000e+03
#                                                    mean   4.534942e+07
#                                                    std    1.726265e+08
#                                                    min    0.000000e+00
#                                                    25%    4.825000e+04
#                                                    50%    4.300000e+05
#                                                    75%    1.733500e+06
#                                                    max    1.642246e+09
# Goodwill                                           count  1.786000e+03
#                                                    mean   2.352682e+08
#                                                    std    4.743548e+08
#                                                    min    0.000000e+00
#                                                    25%    2.836000e+06
#                                                    50%    8.278800e+07
#                                                    75%    2.646792e+08
#                                                    max    7.299354e+09
# Share Based Compensation                           count  1.786000e+03
#                                                    mean   1.079241e+07
#                                                    std    1.358905e+07
#                                                    min   -6.356767e+06
#                                                    25%    3.164250e+06
#                                                    50%    7.166500e+06
#                                                    75%    1.373975e+07
#                                                    max    1.629000e+08
# Weighted Average Number Of Shares Outstanding B... count  1.786000e+03
#                                                    mean   5.672145e+07
#                                                    std    5.370095e+07
#                                                    min    0.000000e+00
#                                                    25%    2.672572e+07
#                                                    50%    4.120700e+07
#                                                    75%    6.982679e+07
#                                                    max    4.419000e+08
# Retained Earnings Accumulated Deficit              count  1.786000e+03
#                                                    mean   1.799204e+08
#                                                    std    3.021178e+09
#                                                    min   -6.939330e+10
#                                                    25%    0.000000e+00
#                                                    50%    2.231155e+08
#                                                    75%    5.349022e+08
#                                                    max    7.031333e+09
# Stockholders Equity                                count  1.786000e+03
#                                                    mean   7.551822e+08
#                                                    std    8.155673e+08
#                                                    min   -1.203300e+09
#                                                    25%    3.062142e+08
#                                                    50%    5.565550e+08
#                                                    75%    9.531998e+08
#                                                    max    8.732100e+09
# Assets                                             count  1.786000e+03
#                                                    mean   2.909386e+09
#                                                    std    4.374051e+09
#                                                    min    0.000000e+00
#                                                    25%    7.602400e+08
#                                                    50%    1.549156e+09
#                                                    75%    3.238893e+09
#                                                    max    6.203074e+10

# %%
xaxis = feature_importance.iloc[0]['Features']
yaxis = feature_importance.iloc[1]['Features']
target = 'cap'

# %%
fig, ax = plt.subplots()
preprocessed.plot.scatter(
    x=xaxis, 
    y=yaxis,
    c=target,
    ax=ax,
    cmap='rainbow',
    figsize=(20, 10)
);

# %%
xlim = ax.get_xlim()
ylim = ax.get_ylim()
ax_log = plt.subplot()
preprocessed.plot.scatter(
    x=xaxis, 
    y=yaxis,
    c=target,
    ax=ax_log,
    cmap='rainbow',
    figsize=(20, 10)
)
ax_log.set_xscale('log')
ax_log.set_yscale('log')
ax_log.set_xlim((xlim[1] / 100_000_000, xlim[1])),
ax_log.set_ylim((xlim[1] / 10_000, ylim[1]));

# %% [markdown]
# ---

# %% [markdown]
# ## Improvement To Model

# %% [markdown]
# - We could use more years of data (i.e. before 2009 and after 2019)
