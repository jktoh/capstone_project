# %% [markdown]
# # Exploratory Data Analysis (EDA) and Cleaning | S&P 1500 Companies
# ---

# %% [markdown]
# ## Import libraries and modules

# %%
# Basic libraries
import numpy as np
import pandas as pd

# Plotting libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /Users/junkai/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Load Pivoted Data

# %% [markdown]
# - Load `pivot_sp500.csv` and `pivot_sp1000.csv` from `data` folder into a pandas DataFrame
# - Check data types for each columns

# %%
edgar_sp500 = pd.read_csv('../data/pivot_sp500.csv', low_memory=False)
edgar_sp500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3065 entries, 0 to 3064
# Columns: 47929 entries, A A G Mandatorily Convertible Preferred Stock to year
# dtypes: float64(38240), int64(1), object(9688)
# memory usage: 1.1+ GB

# %%
edgar_sp1000 = pd.read_csv('../data/pivot_sp1000.csv', low_memory=False)
edgar_sp1000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4918 entries, 0 to 4917
# Columns: 60002 entries, A A C Note Securedby R M B S Securities Value Not Less Than to year
# dtypes: float64(49206), int64(1), object(10795)
# memory usage: 2.2+ GB

# %% [markdown]
# ---

# %% [markdown]
# ## Concatenate `edgar_sp500` and `edgar_sp1000`

# %%
df = pd.concat((edgar_sp500, edgar_sp1000)).reset_index(drop=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7983 entries, 0 to 7982
# Columns: 98308 entries, A A G Mandatorily Convertible Preferred Stock to Zero Point Five Percent Decrease In Expected Long Term Rate Of Return On Plan Assets Estimated Effect On Pension Expense
# dtypes: float64(79662), int64(1), object(18645)
# memory usage: 5.8+ GB

# %% [markdown]
# ---

# %%
df = df[df.isnull().sum().sort_values()[:50].index]

# %%
float_fs = sorted([f for f in df.columns if df[f].dtypes != 'O'])

# %%
df[float_fs] = df[float_fs].fillna(0).astype(float)
df['Document Period End Date'] = pd.to_datetime(df['Document Period End Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7983 entries, 0 to 7982
# Data columns (total 50 columns):
#  #   Column                                                                            Non-Null Count  Dtype
# ---  ------                                                                            --------------  -----
#  0   security                                                                          7983 non-null   object
#  1   year                                                                              7983 non-null   float64
#  2   Cash And Cash Equivalents At Carrying Value                                       7983 non-null   float64
#  3   Income Tax Expense Benefit                                                        7983 non-null   float64
#  4   Stockholders Equity                                                               7983 non-null   float64
#  5   Weighted Average Number Of Diluted Shares Outstanding                             7983 non-null   float64
#  6   Weighted Average Number Of Shares Outstanding Basic                               7983 non-null   float64
#  7   Earnings Per Share Diluted                                                        7983 non-null   float64
#  8   Assets                                                                            7983 non-null   float64
#  9   Unrecognized Tax Benefits                                                         7983 non-null   float64
#  10  Earnings Per Share Basic                                                          7983 non-null   float64
#  11  Net Income Loss                                                                   7983 non-null   float64
#  12  Liabilities And Stockholders Equity                                               7983 non-null   float64
#  13  Deferred Income Tax Expense Benefit                                               7983 non-null   float64
#  14  Accumulated Other Comprehensive Income Loss Net Of Tax                            7983 non-null   float64
#  15  Net Cash Provided By Used In Investing Activities                                 7983 non-null   float64
#  16  Net Cash Provided By Used In Financing Activities                                 7983 non-null   float64
#  17  Current Federal Tax Expense Benefit                                               7983 non-null   float64
#  18  Net Cash Provided By Used In Operating Activities                                 7983 non-null   float64
#  19  Comprehensive Income Net Of Tax                                                   7983 non-null   float64
#  20  Retained Earnings Accumulated Deficit                                             7983 non-null   float64
#  21  Cash And Cash Equivalents Period Increase Decrease                                7983 non-null   float64
#  22  Share Based Compensation                                                          7983 non-null   float64
#  23  Current State And Local Tax Expense Benefit                                       7983 non-null   float64
#  24  Goodwill                                                                          7983 non-null   float64
#  25  Property Plant And Equipment Net                                                  7983 non-null   float64
#  26  Deferred Federal Income Tax Expense Benefit                                       7983 non-null   float64
#  27  Common Stock Shares Authorized                                                    7983 non-null   float64
#  28  Operating Income Loss                                                             7983 non-null   float64
#  29  Deferred State And Local Income Tax Expense Benefit                               7983 non-null   float64
#  30  Accumulated Depreciation Depletion And Amortization Property Plant And Equipment  7983 non-null   float64
#  31  Current Income Tax Expense Benefit                                                7983 non-null   float64
#  32  Common Stock Value                                                                7983 non-null   float64
#  33  Common Stock Par Or Stated Value Per Share                                        7983 non-null   float64
#  34  Common Stock Shares Issued                                                        7983 non-null   float64
#  35  Interest Expense                                                                  7983 non-null   float64
#  36  Payments For Repurchase Of Common Stock                                           7983 non-null   float64
#  37  Property Plant And Equipment Gross                                                7983 non-null   float64
#  38  Document Fiscal Year Focus                                                        7983 non-null   float64
#  39  Document Period End Date                                                          4936 non-null   datetime64[ns]
#  40  Current Fiscal Year End Date                                                      4935 non-null   object
#  41  Entity Well Known Seasoned Issuer                                                 4934 non-null   object
#  42  Amendment Flag                                                                    4934 non-null   object
#  43  Entity Central Index Key                                                          7983 non-null   float64
#  44  Document Fiscal Period Focus                                                      4934 non-null   object
#  45  Entity Filer Category                                                             4934 non-null   object
#  46  Document Type                                                                     4934 non-null   object
#  47  Entity Registrant Name                                                            4934 non-null   object
#  48  Entity Voluntary Filers                                                           4934 non-null   object
#  49  Entity Current Reporting Status                                                   4934 non-null   object
# dtypes: datetime64[ns](1), float64(39), object(10)
# memory usage: 3.0+ MB

# %% [markdown]
# ---

# %%
df.isnull().sum(1).value_counts()
# Out:
# 0     4933
# 10    3045
# 9        3
# 2        1
# 8        1
# dtype: int64

# %%
df = df[df.isnull().sum(1) == 0]

# %% [markdown]
# ---

# %% [markdown]
# ## Plotting And Interpreting Data

# %% [markdown]
# ### Distribution Boxplot Of Values By Features

# %%
nrows = len(float_fs)
fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(20, 5 * nrows))
for n, f in enumerate(float_fs):
    sns.boxplot(x=f, data=df, ax=ax[n, 0])
    ax[n, 0].set_title(f)
    ax[n, 0].set_xlabel('')
    ax[n, 0].set_xscale('log')
    
    sns.violinplot(x=f, data=df, ax=ax[n, 1])
    ax[n, 1].set_title(f)
    ax[n, 1].set_xlabel('')
    ax[n, 1].set_xscale('log')

# %%
df.loc[df['Document Fiscal Year Focus'] < 1300, ['year', 'Document Period End Date', 'Document Fiscal Year Focus']]
# Out:
#         year Document Period End Date  Document Fiscal Year Focus
# 1522  2015.0               2015-12-31                      1215.0
# 1523  2016.0               2016-12-31                      1216.0
# 1524  2017.0               2017-12-31                      1217.0
# 1525  2018.0               2018-12-31                      1218.0

# %% [markdown]
# There's an obvious error in `Document Fiscal Year Focus` as majority of the data lies within the 2010s. Since the correct value is the same as `year` and `Document Period End Date`, to drop this feature.

# %%
df.drop(
    columns=['Document Fiscal Year Focus', 'Entity Central Index Key'],
    inplace=True
)

# %% [markdown]
# ---

# %%
str_fs = sorted([f for f in df.columns if df[f].dtypes == 'O'])
nrows = len(str_fs)
fig, ax = plt.subplots(nrows=nrows, figsize=(20, 15 * nrows))
for n, f in enumerate(str_fs):
    df[f].value_counts().iloc[:60].plot.barh(
        title='Number Of Observation In {}'.format(f),
        ax=ax[n]
    );

# %%
df.drop(
    columns=['Current Fiscal Year End Date', 'Entity Registrant Name'],
    inplace=True
)

# %% [markdown]
# ---

# %% [markdown]
# ### Generate a line plot for `Document Period End Date` with time on the $x$-axis.

# %%
df['Document Period End Date'].value_counts().plot(
    figsize=(20, 15), 
    title='Number of Observation By Document Period End Date'
);

# %% [markdown]
# - There are clearly spikes at the end of every years. This is likely due to most companies having fiscal year end dates on 31 December.

# %% [markdown]
# ---

# %% [markdown]
# ### Visualize Correlation Using A Heat Map

# %%
df_corr = df.corr()
mask = np.zeros_like(df_corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
plt.figure(figsize=(40, 30))
sns.heatmap(df_corr,
            cmap='coolwarm',
            center=0,
            annot=True,
            mask=mask);

# %%
# To drop one of the two features with correlation of 1
df.drop(
    columns=[
        'Earnings Per Share Diluted',
        'Liabilities And Stockholders Equity',
        'Weighted Average Number Of Diluted Shares Outstanding'
    ],
    inplace=True
)

# %% [markdown]
# ---

# %% [markdown]
# ## Export To `csv`

# %%
df.to_csv('../data/clean.csv', index=False)
