# %% [markdown]
# # Capstone Project Part 03: EDA and Cleaning

# %%
import numpy as np
import pandas as pd

# %%
edgar = pd.read_csv('../data/edgar.csv')

# %%
edgar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11241933 entries, 0 to 11241932
# Data columns (total 5 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   security     object
#  1   name         object
#  2   value        object
#  3   unit_ref     object
#  4   context_ref  object
# dtypes: object(5)
# memory usage: 428.8+ MB

# %%
edgar.isnull().sum().plot.barh(
    figsize=(20, 15), 
    title='Number of Missing Observation By Features'
);

# %% [markdown]
# ---

# %%
edgar['security'].value_counts()[:60].plot.barh(
    figsize=(20, 15), 
    title='Number of Observation By Securities'
);

# %%
edgar['name'].value_counts()[:60].plot.barh(
    figsize=(20, 20),
    title='Number of Observation By Accounts'
);

# %%
edgar['value'].value_counts()[:60].plot.barh(
    figsize=(20, 15),
    title='Number of Observation By Values'
);

# %%
edgar['unit_ref'].value_counts()[:60].plot.barh(
    figsize=(20, 15),
    title='Number of Observation By Unit References'
);

# %%
edgar['context_ref'].value_counts()[:60].plot.barh(
    figsize=(20, 20),
    title='Number of Observation By Context References'
);

# %% [markdown]
# ---

# %%
edgar = edgar[
    edgar['value'].notnull()
]

# %%
edgar['number'] = pd.to_numeric(edgar['value'], errors='coerce')

# %%
edgar.loc[
    edgar[
        edgar['number'].notnull()
    ].index, 
    'value'
] = np.nan

# %%
edgar[edgar['number'] == 0].shape
# Out:
# (1003390, 6)

# %%
edgar.drop(index=edgar[edgar['number'] == 0].index, inplace=True)

# %% [markdown]
# ---

# %%
edgar.boxplot(
    column='number', 
    figsize=(20, 15)
);

# %%
edgar[
    edgar['number'] > 100_000_000_000_000_000
]
# Out:
#               security                 name value unit_ref      context_ref  \
# 281293  Albemarle Corp  Entity Public Float   NaN    Unit1  As_Of_6_30_2011
#
#               number
# 281293  6.300000e+18

# %%
edgar[
    (edgar['security'] == 'Albemarle Corp') & 
    (edgar['name'] == 'Entity Public Float')
]
# Out:
#               security                 name value     unit_ref  \
# 264030  Albemarle Corp  Entity Public Float   NaN          usd
# 266421  Albemarle Corp  Entity Public Float   NaN          usd
# 268933  Albemarle Corp  Entity Public Float   NaN          usd
# 271510  Albemarle Corp  Entity Public Float   NaN          usd
# 274131  Albemarle Corp  Entity Public Float   NaN          usd
# 278857  Albemarle Corp  Entity Public Float   NaN          usd
# 278869  Albemarle Corp  Entity Public Float   NaN  iso4217_USD
# 281293  Albemarle Corp  Entity Public Float   NaN        Unit1
# 283068  Albemarle Corp  Entity Public Float   NaN        Unit1
#
#                                       context_ref        number
# 264030                                   FI2018Q2  1.020000e+10
# 266421                                   FI2017Q2  1.170000e+10
# 268933                                   FI2016Q2  8.900000e+09
# 271510                                   FI2015Q2  6.200000e+09
# 274131                                   FI2014Q2  5.600000e+09
# 278857                              I2013Q2June28  5.100000e+09
# 278869  eol_PE8245----1210-K0011_STD_0_20120629_0  5.300000e+09
# 281293                            As_Of_6_30_2011  6.300000e+18
# 283068                            As_Of_6_30_2010  3.600000e+09

# %%
edgar.loc[
    edgar['number'] > 10_000_000_000_000_000, 
    'number'
] /= 1_000_000_000

# %% [markdown]
# ---

# %%
edgar[
    (edgar['number'] > 80_000_000_000_000) | 
    (edgar['number'] < -10_000_000_000_000)
]
# Out:
#                              security  \
# 86435             Activision Blizzard
# 87764             Activision Blizzard
# 263386           Alaska Air Group Inc
# 1623136                Boeing Company
# 3271821               Dominion Energy
# 3271822               Dominion Energy
# 4287240           Fifth Third Bancorp
# 4287307           Fifth Third Bancorp
# 4287873           Fifth Third Bancorp
# 4288821           Fifth Third Bancorp
# 4289712           Fifth Third Bancorp
# 5942059                       KeyCorp
# 5942120                       KeyCorp
# 5943111                       KeyCorp
# 5943112                       KeyCorp
# 5943195                       KeyCorp
# 6327327              Lincoln National
# 7218526   National Oilwell Varco Inc.
# 7218554   National Oilwell Varco Inc.
# 7218563   National Oilwell Varco Inc.
# 7220090   National Oilwell Varco Inc.
# 7220123   National Oilwell Varco Inc.
# 7220132   National Oilwell Varco Inc.
# 7479988          Northern Trust Corp.
# 7479989          Northern Trust Corp.
# 7480512          Northern Trust Corp.
# 7480513          Northern Trust Corp.
# 7481066          Northern Trust Corp.
# 7481067          Northern Trust Corp.
# 9341312            Skyworks Solutions
# 10075699                 U.S. Bancorp
# 10075700                 U.S. Bancorp
# 10075701                 U.S. Bancorp
#
#                                                        name value unit_ref  \
# 86435                                   Entity Public Float   NaN      USD
# 87764                                   Entity Public Float   NaN      USD
# 263386                                  Entity Public Float   NaN      usd
# 1623136                             Stock Shares Terminated   NaN   Unit14
# 3271821        Notional Amount Of Interest Rate Derivatives   NaN      usd
# 3271822        Notional Amount Of Interest Rate Derivatives   NaN      usd
# 4287240                                  Shares Outstanding   NaN   shares
# 4287307                                  Shares Outstanding   NaN   shares
# 4287873                                  Shares Outstanding   NaN   shares
# 4288821                                  Shares Outstanding   NaN   shares
# 4289712        Stock Issued During Period Shares New Issues   NaN   shares
# 5942059                      Common Stock Shares Authorized   NaN   shares
# 5942120                          Common Stock Shares Issued   NaN   shares
# 5943111                               Treasury Stock Shares   NaN   shares
# 5943112                      Common Stock Shares Authorized   NaN   shares
# 5943195                          Common Stock Shares Issued   NaN   shares
# 6327327                                 Entity Public Float   NaN      USD
# 7218526   Sharebased Compensation Arrangement By Shareba...   NaN      USD
# 7218554   Share Based Compensation Arrangement By Share ...   NaN      USD
# 7218563   Share Based Compensation Arrangement By Share ...   NaN      USD
# 7220090   Share Based Compensation Arrangement By Share ...   NaN      USD
# 7220123   Share Based Compensation Arrangement By Share ...   NaN      USD
# 7220132   Share Based Compensation Arrangement By Share ...   NaN      USD
# 7479988   Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7479989   Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7480512   Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7480513   Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7481066   Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7481067   Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 9341312                                 Entity Public Float   NaN      usd
# 10075699  Share Based Compensation Arrangement By Share ...   NaN   Shares
# 10075700  Share Based Compensation Arrangement By Share ...   NaN   Shares
# 10075701  Share Based Compensation Arrangement By Share ...   NaN   Shares
#
#                                                 context_ref        number
# 86435                                      AS_OF_Jun30_2011  4.843917e+15
# 87764                                      AS_OF_Jun30_2010  5.230966e+15
# 263386                                   I2010Q2PublicFloat  1.600000e+15
# 1623136                     Duration_1_1_2010_To_12_31_2010 -2.994892e+13
# 3271821   I2012Q4_dei_LegalEntityAxis_d_VirginiaElectric...  5.000000e+14
# 3271822   I2012Q4_dei_LegalEntityAxis_d_VirginiaElectric...  2.500000e+14
# 4287240   eol_PE7793----1010-K0029_STD_0_20071231_0_4118...  5.834271e+14
# 4287307   eol_PE7793----1010-K0029_STD_0_20081231_0_4118...  5.834271e+14
# 4287873   eol_PE7793----1010-K0029_STD_0_20091231_0_4118...  8.015042e+14
# 4288821   eol_PE7793----1010-K0029_STD_0_20101231_0_4118...  8.015042e+14
# 4289712   eol_PE7793----1010-K0029_STD_365_20091231_0_41...  1.579560e+14
# 5942059           eol_PE1080----1210-K0009_STD_0_20111231_0  1.400000e+15
# 5942120           eol_PE1080----1210-K0009_STD_0_20111231_0  1.016970e+15
# 5943111           eol_PE1080----1210-K0009_STD_0_20121231_0  9.120128e+13
# 5943112           eol_PE1080----1210-K0009_STD_0_20121231_0  1.400000e+15
# 5943195           eol_PE1080----1210-K0009_STD_0_20121231_0  1.016970e+15
# 6327327                                    AS_OF_Dec31_2011  8.800000e+15
# 7218526                               BalanceAsOf_31Dec2011  1.497877e+14
# 7218554                               BalanceAsOf_31Dec2011  2.179510e+14
# 7218563                               BalanceAsOf_31Dec2011  2.141368e+14
# 7220090                             Jan-01-2010_Dec-31-2010  1.527423e+14
# 7220123                               BalanceAsOf_31Dec2010  3.124238e+14
# 7220132                               BalanceAsOf_31Dec2010  3.043945e+14
# 7479988         eol_PE10923---1010-K0021_STD_365_20091231_0  2.364160e+14
# 7479989         eol_PE10923---1010-K0021_STD_365_20091231_0  2.355119e+14
# 7480512         eol_PE10923---1010-K0021_STD_365_20101231_0  2.425025e+14
# 7480513         eol_PE10923---1010-K0021_STD_365_20101231_0  2.420288e+14
# 7481066         eol_PE10923---1010-K0021_STD_366_20081231_0  2.240534e+14
# 7481067         eol_PE10923---1010-K0021_STD_366_20081231_0  2.214464e+14
# 9341312                                  I2011Q2PublicFloat  5.808023e+15
# 10075699                              BalanceAsOf_31Dec2008  8.229301e+13
# 10075700                              BalanceAsOf_31Dec2009  8.837947e+13
# 10075701                              BalanceAsOf_31Dec2010  8.562270e+13

# %%
edgar[
    (edgar['security'] == 'Activision Blizzard') & 
    (edgar['name'] == 'Entity Public Float')
]
# Out:
#                   security                 name value unit_ref  \
# 75516  Activision Blizzard  Entity Public Float   NaN      usd
# 77081  Activision Blizzard  Entity Public Float   NaN      usd
# 78505  Activision Blizzard  Entity Public Float   NaN      usd
# 79901  Activision Blizzard  Entity Public Float   NaN      usd
# 81036  Activision Blizzard  Entity Public Float   NaN      USD
# 82366  Activision Blizzard  Entity Public Float   NaN      USD
# 83771  Activision Blizzard  Entity Public Float   NaN      USD
# 85103  Activision Blizzard  Entity Public Float   NaN      USD
# 86435  Activision Blizzard  Entity Public Float   NaN      USD
# 87764  Activision Blizzard  Entity Public Float   NaN      USD
#
#             context_ref        number
# 75516          FI2018Q2  5.744746e+10
# 77081          FI2017Q2  4.258734e+10
# 78505          FI2016Q2  2.788457e+10
# 79901          FI2015Q2  1.334568e+10
# 81036  AS_OF_Jun30_2014  1.183686e+10
# 82366  AS_OF_Jun28_2013  5.992872e+09
# 83771  AS_OF_Jun29_2012  4.910586e+09
# 85103  AS_OF_Jun29_2012  4.910586e+09
# 86435  AS_OF_Jun30_2011  4.843917e+15
# 87764  AS_OF_Jun30_2010  5.230966e+15

# %%
edgar[
    (edgar['security'] == 'Alaska Air Group Inc') & 
    (edgar['name'] == 'Entity Public Float')
]
# Out:
#                     security                 name value unit_ref  \
# 250802  Alaska Air Group Inc  Entity Public Float   NaN      usd
# 252461  Alaska Air Group Inc  Entity Public Float   NaN      usd
# 253947  Alaska Air Group Inc  Entity Public Float   NaN      usd
# 255431  Alaska Air Group Inc  Entity Public Float   NaN      usd
# 256823  Alaska Air Group Inc  Entity Public Float   NaN      usd
# 259774  Alaska Air Group Inc  Entity Public Float   NaN      usd
# 261389  Alaska Air Group Inc  Entity Public Float   NaN      usd
# 263148  Alaska Air Group Inc  Entity Public Float   NaN      usd
# 263386  Alaska Air Group Inc  Entity Public Float   NaN      usd
#
#                context_ref        number
# 250802            FI2018Q2  7.400000e+09
# 252461            FI2016Q2  1.110000e+10
# 253947            FI2015Q2  7.100000e+09
# 255431            FI2015Q2  8.200000e+09
# 256823            FI2014Q2  6.400000e+09
# 259774            FI2013Q2  3.600000e+09
# 261389             I2012Q2  2.500000e+09
# 263148             I2011Q2  2.500000e+09
# 263386  I2010Q2PublicFloat  1.600000e+15

# %%
edgar[
    (edgar['security'] == 'Boeing Company') & 
    (edgar['name'] == 'Stock Shares Terminated')
]
# Out:
#                security                     name value unit_ref  \
# 1620214  Boeing Company  Stock Shares Terminated   NaN   shares
# 1620600  Boeing Company  Stock Shares Terminated   NaN   Unit14
# 1623136  Boeing Company  Stock Shares Terminated   NaN   Unit14
#
#                              context_ref        number
# 1620214                       D2010Q4YTD -2.994892e+07
# 1620600  Duration_1_1_2010_To_12_31_2010 -2.994892e+07
# 1623136  Duration_1_1_2010_To_12_31_2010 -2.994892e+13

# %%
edgar[
    (edgar['security'] == 'Dominion Energy') & 
    (edgar['name'] == 'Notional Amount Of Interest Rate Derivatives')
]
# Out:
#                 security                                          name value  \
# 3271819  Dominion Energy  Notional Amount Of Interest Rate Derivatives   NaN
# 3271820  Dominion Energy  Notional Amount Of Interest Rate Derivatives   NaN
# 3271821  Dominion Energy  Notional Amount Of Interest Rate Derivatives   NaN
# 3271822  Dominion Energy  Notional Amount Of Interest Rate Derivatives   NaN
# 3275752  Dominion Energy  Notional Amount Of Interest Rate Derivatives   NaN
# 3275753  Dominion Energy  Notional Amount Of Interest Rate Derivatives   NaN
# 3279696  Dominion Energy  Notional Amount Of Interest Rate Derivatives   NaN
#
#         unit_ref                                        context_ref  \
# 3271819      usd  I2012Q4_us-gaap_DerivativeInstrumentRiskAxis_d...
# 3271820      usd  I2012Q4_us-gaap_DerivativeInstrumentRiskAxis_d...
# 3271821      usd  I2012Q4_dei_LegalEntityAxis_d_VirginiaElectric...
# 3271822      usd  I2012Q4_dei_LegalEntityAxis_d_VirginiaElectric...
# 3275752      usd  I2011Q4_us-gaap_DerivativeInstrumentRiskAxis_d...
# 3275753      usd  I2011Q4_us-gaap_DerivativeInstrumentRiskAxis_d...
# 3279696    Unit1                               As_Of_12_31_20107231
#
#                number
# 3271819  2.250000e+09
# 3271820  1.500000e+09
# 3271821  5.000000e+14
# 3271822  2.500000e+14
# 3275752  2.090000e+09
# 3275753  2.200000e+09
# 3279696  1.000000e+09

# %%
edgar[
    (edgar['security'] == 'Fifth Third Bancorp') & 
    (edgar['name'] == 'Shares Outstanding')
]
# Out:
#                     security                name value unit_ref  \
# 4252391  Fifth Third Bancorp  Shares Outstanding   NaN   shares
# 4252392  Fifth Third Bancorp  Shares Outstanding   NaN   shares
# 4252393  Fifth Third Bancorp  Shares Outstanding   NaN   shares
# 4252394  Fifth Third Bancorp  Shares Outstanding   NaN   shares
# 4252395  Fifth Third Bancorp  Shares Outstanding   NaN   shares
# ...                      ...                 ...   ...      ...
# 4287878  Fifth Third Bancorp  Shares Outstanding   NaN   shares
# 4287891  Fifth Third Bancorp  Shares Outstanding   NaN   shares
# 4288821  Fifth Third Bancorp  Shares Outstanding   NaN   shares
# 4288826  Fifth Third Bancorp  Shares Outstanding   NaN   shares
# 4288843  Fifth Third Bancorp  Shares Outstanding   NaN   shares
#
#                                                context_ref        number
# 4252391  AS_OF_Dec31_2017_Entity_0000035527_us-gaap_Sta...  9.238926e+08
# 4252392  AS_OF_Dec31_2015_Entity_0000035527_us-gaap_Sta...  9.238926e+08
# 4252393  AS_OF_Dec31_2015_Entity_0000035527_us-gaap_Sta...  5.400000e+04
# 4252394  AS_OF_Dec31_2017_Entity_0000035527_us-gaap_Sta...  5.400000e+04
# 4252395  AS_OF_Dec31_2016_Entity_0000035527_us-gaap_Sta...  5.400000e+04
# ...                                                    ...           ...
# 4287878  eol_PE7793----1010-K0029_STD_0_20091231_0_4118...  1.527710e+11
# 4287891  eol_PE7793----1010-K0029_STD_0_20091231_0_4118...  6.436024e+12
# 4288821  eol_PE7793----1010-K0029_STD_0_20101231_0_4118...  8.015042e+14
# 4288826  eol_PE7793----1010-K0029_STD_0_20101231_0_4118...  1.527710e+11
# 4288843  eol_PE7793----1010-K0029_STD_0_20101231_0_4118...  5.231666e+12
#
# [108 rows x 6 columns]

# %% [markdown]
# Noted the numbers should be 583,427,104 (`4287240` and `4287307`), 801,504,188 (`4287873` and `4288821`), and 51,482,500 (`4287244`) respectively, from https://www.sec.gov/cgi-bin/viewer?action=view&cik=35527&accession_number=0001193125-11-049817&xbrl_type=v#.

# %%
edgar.loc[
    (edgar['security'] == 'Fifth Third Bancorp') &
    (edgar['name'] == 'Shares Outstanding') &
    (edgar['number'] > 10_000_000_000_000),
    'number'
] /= 1_000_000

# %%
edgar[
    (edgar['security'] == 'Fifth Third Bancorp') & 
    (edgar['name'] == 'Stock Issued During Period Shares New Issues')
]
# Out:
#                     security                                          name  \
# 4265044  Fifth Third Bancorp  Stock Issued During Period Shares New Issues
# 4268219  Fifth Third Bancorp  Stock Issued During Period Shares New Issues
# 4268220  Fifth Third Bancorp  Stock Issued During Period Shares New Issues
# 4268222  Fifth Third Bancorp  Stock Issued During Period Shares New Issues
# 4268261  Fifth Third Bancorp  Stock Issued During Period Shares New Issues
# 4272600  Fifth Third Bancorp  Stock Issued During Period Shares New Issues
# 4272601  Fifth Third Bancorp  Stock Issued During Period Shares New Issues
# 4272603  Fifth Third Bancorp  Stock Issued During Period Shares New Issues
# 4272634  Fifth Third Bancorp  Stock Issued During Period Shares New Issues
# 4277015  Fifth Third Bancorp  Stock Issued During Period Shares New Issues
# 4281399  Fifth Third Bancorp  Stock Issued During Period Shares New Issues
# 4285699  Fifth Third Bancorp  Stock Issued During Period Shares New Issues
# 4285703  Fifth Third Bancorp  Stock Issued During Period Shares New Issues
# 4285752  Fifth Third Bancorp  Stock Issued During Period Shares New Issues
# 4289177  Fifth Third Bancorp  Stock Issued During Period Shares New Issues
# 4289712  Fifth Third Bancorp  Stock Issued During Period Shares New Issues
#
#         value unit_ref                                        context_ref  \
# 4265044   NaN   shares  FROM_Jan01_2014_TO_Dec31_2014_Entity_000003552...
# 4268219   NaN   Shares  FROM_Jan01_2013_TO_Dec31_2013_us-gaap_Statemen...
# 4268220   NaN   Shares  FROM_Jan01_2013_TO_Dec31_2013_us-gaap_Statemen...
# 4268222   NaN   Shares  FROM_Jan01_2014_TO_Dec31_2014_us-gaap_Statemen...
# 4268261   NaN   Shares  FROM_Jan01_2013_TO_Dec31_2013_us-gaap_Statemen...
# 4272600   NaN   Shares  FROM_Jan01_2013_TO_Dec31_2013_us-gaap_Statemen...
# 4272601   NaN   Shares  FROM_Jan01_2013_TO_Dec31_2013_us-gaap_Statemen...
# 4272603   NaN   Shares  FROM_Jan01_2014_TO_Dec31_2014_us-gaap_Statemen...
# 4272634   NaN   Shares  FROM_Jan01_2013_TO_Dec31_2013_us-gaap_Statemen...
# 4277015   NaN   Shares  FROM_Jan01_2011_TO_Dec31_2011_us-gaap_Statemen...
# 4281399   NaN   Shares  FROM_Jan01_2011_TO_Dec31_2011_us-gaap_Statemen...
# 4285699   NaN   Shares  FROM_Jan01_2009_TO_Dec31_2009_us-gaap_Statemen...
# 4285703   NaN   Shares  FROM_Jan01_2011_TO_Dec31_2011_us-gaap_Statemen...
# 4285752   NaN   Shares                      FROM_Jan01_2009_TO_Dec31_2009
# 4289177   NaN   shares  eol_PE7793----1010-K0029_STD_30_20090630_0_411...
# 4289712   NaN   shares  eol_PE7793----1010-K0029_STD_365_20091231_0_41...
#
#                number
# 4265044  1.200000e+04
# 4268219  1.800000e+04
# 4268220  2.400000e+04
# 4268222  1.200000e+04
# 4268261  3.551174e+07
# 4272600  1.800000e+04
# 4272601  2.400000e+04
# 4272603  1.200000e+04
# 4272634  3.551174e+07
# 4277015  1.223884e+08
# 4281399  1.223884e+08
# 4285699  1.579560e+08
# 4285703  1.223884e+08
# 4285752  6.000000e+07
# 4289177  6.000000e+07
# 4289712  1.579560e+14

# %%
edgar[
    (edgar['security'] == 'KeyCorp') & 
    (edgar['name'] == 'Common Stock Shares Authorized')
]
# Out:
#         security                            name value unit_ref  \
# 5917201  KeyCorp  Common Stock Shares Authorized   NaN   shares
# 5917202  KeyCorp  Common Stock Shares Authorized   NaN   shares
# 5922604  KeyCorp  Common Stock Shares Authorized   NaN   shares
# 5922605  KeyCorp  Common Stock Shares Authorized   NaN   shares
# 5926525  KeyCorp  Common Stock Shares Authorized   NaN   shares
# 5927642  KeyCorp  Common Stock Shares Authorized   NaN   shares
# 5931508  KeyCorp  Common Stock Shares Authorized   NaN   shares
# 5932658  KeyCorp  Common Stock Shares Authorized   NaN   shares
# 5936502  KeyCorp  Common Stock Shares Authorized   NaN   shares
# 5937947  KeyCorp  Common Stock Shares Authorized   NaN   shares
# 5942059  KeyCorp  Common Stock Shares Authorized   NaN   shares
# 5943112  KeyCorp  Common Stock Shares Authorized   NaN   shares
# 5949303  KeyCorp  Common Stock Shares Authorized   NaN   Shares
# 5949304  KeyCorp  Common Stock Shares Authorized   NaN   Shares
# 5953620  KeyCorp  Common Stock Shares Authorized   NaN   Shares
# 5953621  KeyCorp  Common Stock Shares Authorized   NaN   Shares
#
#                                        context_ref        number
# 5917201                                   FI2016Q4  1.400000e+09
# 5917202                                   FI2017Q4  1.400000e+09
# 5922604                                   FI2015Q4  1.400000e+09
# 5922605                                   FI2016Q4  1.400000e+09
# 5926525  eol_PE1080----1510-K0011_STD_0_20141231_0  1.400000e+09
# 5927642  eol_PE1080----1510-K0011_STD_0_20151231_0  1.400000e+09
# 5931508  eol_PE1080----1410-K0012_STD_0_20131231_0  1.400000e+09
# 5932658  eol_PE1080----1410-K0012_STD_0_20141231_0  1.400000e+09
# 5936502  eol_PE1080----1310-K0013_STD_0_20121231_0  1.400000e+09
# 5937947  eol_PE1080----1310-K0013_STD_0_20131231_0  1.400000e+09
# 5942059  eol_PE1080----1210-K0009_STD_0_20111231_0  1.400000e+15
# 5943112  eol_PE1080----1210-K0009_STD_0_20121231_0  1.400000e+15
# 5949303                      BalanceAsOf_31Dec2010  1.400000e+09
# 5949304                      BalanceAsOf_31Dec2011  1.400000e+09
# 5953620                      BalanceAsOf_31Dec2009  1.400000e+09
# 5953621                      BalanceAsOf_31Dec2010  1.400000e+09

# %%
edgar[
    (edgar['security'] == 'KeyCorp') & 
    (edgar['name'] == 'Common Stock Shares Issued')
]
# Out:
#         security                        name value unit_ref  \
# 5917203  KeyCorp  Common Stock Shares Issued   NaN   shares
# 5917204  KeyCorp  Common Stock Shares Issued   NaN   shares
# 5917205  KeyCorp  Common Stock Shares Issued   NaN   shares
# 5922606  KeyCorp  Common Stock Shares Issued   NaN   shares
# 5922607  KeyCorp  Common Stock Shares Issued   NaN   shares
# 5922608  KeyCorp  Common Stock Shares Issued   NaN   shares
# 5926524  KeyCorp  Common Stock Shares Issued   NaN   shares
# 5927640  KeyCorp  Common Stock Shares Issued   NaN   shares
# 5928072  KeyCorp  Common Stock Shares Issued   NaN   shares
# 5931507  KeyCorp  Common Stock Shares Issued   NaN   shares
# 5932656  KeyCorp  Common Stock Shares Issued   NaN   shares
# 5933111  KeyCorp  Common Stock Shares Issued   NaN   shares
# 5936564  KeyCorp  Common Stock Shares Issued   NaN   shares
# 5938031  KeyCorp  Common Stock Shares Issued   NaN   shares
# 5938956  KeyCorp  Common Stock Shares Issued   NaN   shares
# 5942120  KeyCorp  Common Stock Shares Issued   NaN   shares
# 5943195  KeyCorp  Common Stock Shares Issued   NaN   shares
# 5949305  KeyCorp  Common Stock Shares Issued   NaN   Shares
# 5949306  KeyCorp  Common Stock Shares Issued   NaN   Shares
# 5953622  KeyCorp  Common Stock Shares Issued   NaN   Shares
# 5953623  KeyCorp  Common Stock Shares Issued   NaN   Shares
#
#                                                context_ref        number
# 5917203                                           FI2016Q4  1.256702e+09
# 5917204                                           FI2017Q4  1.256702e+09
# 5917205   FI2017Q4_us-gaap_RangeAxis_us-gaap_MaximumMember  3.000000e+06
# 5922606                                           FI2015Q4  1.016970e+09
# 5922607                                           FI2016Q4  1.256702e+09
# 5922608   FI2016Q4_us-gaap_RangeAxis_us-gaap_MaximumMember  3.000000e+06
# 5926524          eol_PE1080----1510-K0011_STD_0_20141231_0  1.016970e+09
# 5927640          eol_PE1080----1510-K0011_STD_0_20151231_0  1.016970e+09
# 5928072  eol_PE1080----1510-K0011_STD_0_20151231_0_1269...  3.000000e+06
# 5931507          eol_PE1080----1410-K0012_STD_0_20131231_0  1.016970e+09
# 5932656          eol_PE1080----1410-K0012_STD_0_20141231_0  1.016970e+09
# 5933111  eol_PE1080----1410-K0012_STD_0_20141231_0_1269...  3.000000e+06
# 5936564          eol_PE1080----1310-K0013_STD_0_20121231_0  1.016970e+09
# 5938031          eol_PE1080----1310-K0013_STD_0_20131231_0  1.016970e+09
# 5938956  eol_PE1080----1310-K0013_STD_0_20131231_0_5689...  3.000000e+06
# 5942120          eol_PE1080----1210-K0009_STD_0_20111231_0  1.016970e+15
# 5943195          eol_PE1080----1210-K0009_STD_0_20121231_0  1.016970e+15
# 5949305                              BalanceAsOf_31Dec2010  9.463484e+08
# 5949306                              BalanceAsOf_31Dec2011  1.016970e+09
# 5953622                              BalanceAsOf_31Dec2009  9.463484e+08
# 5953623                              BalanceAsOf_31Dec2010  9.463484e+08

# %%
edgar[
    (edgar['security'] == 'KeyCorp') & 
    (edgar['name'] == 'Treasury Stock Shares')
]
# Out:
#         security                   name value unit_ref  \
# 5920729  KeyCorp  Treasury Stock Shares   NaN   shares
# 5920730  KeyCorp  Treasury Stock Shares   NaN   shares
# 5926098  KeyCorp  Treasury Stock Shares   NaN   shares
# 5926099  KeyCorp  Treasury Stock Shares   NaN   shares
# 5926528  KeyCorp  Treasury Stock Shares   NaN   shares
# 5927647  KeyCorp  Treasury Stock Shares   NaN   shares
# 5931511  KeyCorp  Treasury Stock Shares   NaN   shares
# 5932663  KeyCorp  Treasury Stock Shares   NaN   shares
# 5936501  KeyCorp  Treasury Stock Shares   NaN   shares
# 5937946  KeyCorp  Treasury Stock Shares   NaN   shares
# 5942058  KeyCorp  Treasury Stock Shares   NaN   shares
# 5943111  KeyCorp  Treasury Stock Shares   NaN   shares
# 5951467  KeyCorp  Treasury Stock Shares   NaN   Shares
# 5951468  KeyCorp  Treasury Stock Shares   NaN   Shares
# 5955872  KeyCorp  Treasury Stock Shares   NaN   Shares
# 5955873  KeyCorp  Treasury Stock Shares   NaN   Shares
#
#                                        context_ref        number
# 5920729                                   FI2016Q4  1.773884e+08
# 5920730                                   FI2017Q4  1.876178e+08
# 5926098                                   FI2015Q4  1.812186e+08
# 5926099                                   FI2016Q4  1.773884e+08
# 5926528  eol_PE1080----1510-K0011_STD_0_20141231_0  1.575665e+08
# 5927647  eol_PE1080----1510-K0011_STD_0_20151231_0  1.812186e+08
# 5931511  eol_PE1080----1410-K0012_STD_0_20131231_0  1.262455e+08
# 5932663  eol_PE1080----1410-K0012_STD_0_20141231_0  1.575665e+08
# 5936501  eol_PE1080----1310-K0013_STD_0_20121231_0  9.120128e+07
# 5937946  eol_PE1080----1310-K0013_STD_0_20131231_0  1.262455e+08
# 5942058  eol_PE1080----1210-K0009_STD_0_20111231_0  6.396211e+13
# 5943111  eol_PE1080----1210-K0009_STD_0_20121231_0  9.120128e+13
# 5951467                      BalanceAsOf_31Dec2010  6.574073e+07
# 5951468                      BalanceAsOf_31Dec2011  6.396211e+07
# 5955872                      BalanceAsOf_31Dec2009  6.781349e+07
# 5955873                      BalanceAsOf_31Dec2010  6.574073e+07

# %%
edgar.loc[
    (edgar['security'] == 'KeyCorp') &
    (edgar['name'] == 'Treasury Stock Shares') &
    (edgar['number'] > 1_000_000_000),
    'number'
] /= 1_000_000

# %%
edgar[
    (edgar['security'] == 'Lincoln National') & 
    (edgar['name'] == 'Entity Public Float')
]
# Out:
#                  security                 name value unit_ref  \
# 6295312  Lincoln National  Entity Public Float   NaN   Unit12
# 6298986  Lincoln National  Entity Public Float   NaN   Unit12
# 6302647  Lincoln National  Entity Public Float   NaN   Unit12
# 6306427  Lincoln National  Entity Public Float   NaN   Unit12
# 6310150  Lincoln National  Entity Public Float   NaN   Unit12
# 6314222  Lincoln National  Entity Public Float   NaN   Unit12
# 6322801  Lincoln National  Entity Public Float   NaN      USD
# 6327327  Lincoln National  Entity Public Float   NaN      USD
# 6332535  Lincoln National  Entity Public Float   NaN      USD
#
#               context_ref        number
# 6295312   As_Of_6_30_2018  1.200000e+10
# 6298986   As_Of_6_30_2017  1.330000e+10
# 6302647   As_Of_6_30_2016  9.000000e+09
# 6306427   As_Of_6_30_2015  1.480000e+10
# 6310150   As_Of_6_30_2014  1.340000e+10
# 6314222   As_Of_6_30_2013  9.600000e+09
# 6322801  AS_OF_Jun30_2012  6.100000e+09
# 6327327  AS_OF_Dec31_2011  8.800000e+15
# 6332535  AS_OF_Jun30_2010  7.700000e+09

# %%
edgar[
    (edgar['security'] == 'National Oilwell Varco Inc.') & 
    (edgar['name'] == 'Sharebased Compensation Arrangement By Sharebased Payment Award Options Exercisable Intrinsic Value1')
]
# Out:
#                             security  \
# 7206781  National Oilwell Varco Inc.
# 7207731  National Oilwell Varco Inc.
# 7209360  National Oilwell Varco Inc.
# 7211021  National Oilwell Varco Inc.
# 7212788  National Oilwell Varco Inc.
# 7214511  National Oilwell Varco Inc.
# 7216133  National Oilwell Varco Inc.
# 7218526  National Oilwell Varco Inc.
#
#                                                       name value  \
# 7206781  Sharebased Compensation Arrangement By Shareba...   NaN
# 7207731  Sharebased Compensation Arrangement By Shareba...   NaN
# 7209360  Sharebased Compensation Arrangement By Shareba...   NaN
# 7211021  Sharebased Compensation Arrangement By Shareba...   NaN
# 7212788  Sharebased Compensation Arrangement By Shareba...   NaN
# 7214511  Sharebased Compensation Arrangement By Shareba...   NaN
# 7216133  Sharebased Compensation Arrangement By Shareba...   NaN
# 7218526  Sharebased Compensation Arrangement By Shareba...   NaN
#
#              unit_ref                                context_ref        number
# 7206781  U_iso4217USD                      C_0001021860_20181231  4.585760e+05
# 7207731   iso4217_USD  eol_PE10065---1710-K0009_STD_0_20171231_0  1.555732e+07
# 7209360   iso4217_USD  eol_PE10065---1610-K0010_STD_0_20161231_0  6.700856e+06
# 7211021   iso4217_USD  eol_PE10065---1510-K0010_STD_0_20151231_0  5.894977e+06
# 7212788   iso4217_USD  eol_PE10065---1410-K0012_STD_0_20141231_0  8.550322e+07
# 7214511   iso4217_USD  eol_PE10065---1310-K0011_STD_0_20131231_0  1.558921e+08
# 7216133   iso4217_USD  eol_PE10065---1210-K0009_STD_0_20121231_0  1.251924e+08
# 7218526           USD                      BalanceAsOf_31Dec2011  1.497877e+14

# %%
edgar[
    (edgar['security'] == 'National Oilwell Varco Inc.') & 
    (edgar['name'] == 'Share Based Compensation Arrangement By Share Based Payment Award Options Outstanding Intrinsic Value')
]
# Out:
#                             security  \
# 7206779  National Oilwell Varco Inc.
# 7206780  National Oilwell Varco Inc.
# 7207500  National Oilwell Varco Inc.
# 7207736  National Oilwell Varco Inc.
# 7209100  National Oilwell Varco Inc.
# 7209338  National Oilwell Varco Inc.
# 7210814  National Oilwell Varco Inc.
# 7211050  National Oilwell Varco Inc.
# 7212507  National Oilwell Varco Inc.
# 7212771  National Oilwell Varco Inc.
# 7214270  National Oilwell Varco Inc.
# 7214515  National Oilwell Varco Inc.
# 7215794  National Oilwell Varco Inc.
# 7216014  National Oilwell Varco Inc.
# 7218554  National Oilwell Varco Inc.
# 7220123  National Oilwell Varco Inc.
#
#                                                       name value  \
# 7206779  Share Based Compensation Arrangement By Share ...   NaN
# 7206780  Share Based Compensation Arrangement By Share ...   NaN
# 7207500  Share Based Compensation Arrangement By Share ...   NaN
# 7207736  Share Based Compensation Arrangement By Share ...   NaN
# 7209100  Share Based Compensation Arrangement By Share ...   NaN
# 7209338  Share Based Compensation Arrangement By Share ...   NaN
# 7210814  Share Based Compensation Arrangement By Share ...   NaN
# 7211050  Share Based Compensation Arrangement By Share ...   NaN
# 7212507  Share Based Compensation Arrangement By Share ...   NaN
# 7212771  Share Based Compensation Arrangement By Share ...   NaN
# 7214270  Share Based Compensation Arrangement By Share ...   NaN
# 7214515  Share Based Compensation Arrangement By Share ...   NaN
# 7215794  Share Based Compensation Arrangement By Share ...   NaN
# 7216014  Share Based Compensation Arrangement By Share ...   NaN
# 7218554  Share Based Compensation Arrangement By Share ...   NaN
# 7220123  Share Based Compensation Arrangement By Share ...   NaN
#
#              unit_ref                                context_ref        number
# 7206779  U_iso4217USD                      C_0001021860_20171231  3.418637e+07
# 7206780  U_iso4217USD                      C_0001021860_20181231  4.585760e+05
# 7207500   iso4217_USD  eol_PE10065---1710-K0009_STD_0_20161231_0  6.700856e+06
# 7207736   iso4217_USD  eol_PE10065---1710-K0009_STD_0_20171231_0  3.418637e+07
# 7209100   iso4217_USD  eol_PE10065---1610-K0010_STD_0_20151231_0  5.894977e+06
# 7209338   iso4217_USD  eol_PE10065---1610-K0010_STD_0_20161231_0  3.792849e+07
# 7210814   iso4217_USD  eol_PE10065---1510-K0010_STD_0_20141231_0  8.550322e+07
# 7211050   iso4217_USD  eol_PE10065---1510-K0010_STD_0_20151231_0  5.894977e+06
# 7212507   iso4217_USD  eol_PE10065---1410-K0012_STD_0_20131231_0  1.558921e+08
# 7212771   iso4217_USD  eol_PE10065---1410-K0012_STD_0_20141231_0  8.799811e+07
# 7214270   iso4217_USD  eol_PE10065---1310-K0011_STD_0_20121231_0  1.506670e+08
# 7214515   iso4217_USD  eol_PE10065---1310-K0011_STD_0_20131231_0  1.838493e+08
# 7215794   iso4217_USD  eol_PE10065---1210-K0009_STD_0_20111231_0  2.179510e+08
# 7216014   iso4217_USD  eol_PE10065---1210-K0009_STD_0_20121231_0  1.506670e+08
# 7218554           USD                      BalanceAsOf_31Dec2011  2.179510e+14
# 7220123           USD                      BalanceAsOf_31Dec2010  3.124238e+14

# %%
edgar[
    (edgar['security'] == 'Northern Trust Corp.') & 
    (edgar['name'] == 'Weighted Average Number Of Diluted Shares Outstanding')
]
# Out:
#                      security  \
# 7452927  Northern Trust Corp.
# 7452928  Northern Trust Corp.
# 7452929  Northern Trust Corp.
# 7456684  Northern Trust Corp.
# 7456685  Northern Trust Corp.
# 7456686  Northern Trust Corp.
# 7460414  Northern Trust Corp.
# 7460415  Northern Trust Corp.
# 7460416  Northern Trust Corp.
# 7464071  Northern Trust Corp.
# 7464072  Northern Trust Corp.
# 7464073  Northern Trust Corp.
# 7466215  Northern Trust Corp.
# 7466727  Northern Trust Corp.
# 7467387  Northern Trust Corp.
# 7469735  Northern Trust Corp.
# 7470127  Northern Trust Corp.
# 7470805  Northern Trust Corp.
# 7473234  Northern Trust Corp.
# 7473598  Northern Trust Corp.
# 7474138  Northern Trust Corp.
# 7476752  Northern Trust Corp.
# 7477105  Northern Trust Corp.
# 7477609  Northern Trust Corp.
# 7479988  Northern Trust Corp.
# 7480512  Northern Trust Corp.
# 7481066  Northern Trust Corp.
#
#                                                       name value unit_ref  \
# 7452927  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7452928  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7452929  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7456684  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7456685  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7456686  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7460414  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7460415  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7460416  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7464071  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7464072  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7464073  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7466215  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7466727  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7467387  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7469735  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7470127  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7470805  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7473234  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7473598  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7474138  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7476752  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7477105  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7477609  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7479988  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7480512  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
# 7481066  Weighted Average Number Of Diluted Shares Outs...   NaN   shares
#
#                                          context_ref        number
# 7452927                                  FD2016Q4YTD  2.291514e+08
# 7452928                                  FD2017Q4YTD  2.296544e+08
# 7452929                                  FD2018Q4YTD  2.244883e+08
# 7456684                                  FD2015Q4YTD  2.342217e+08
# 7456685                                  FD2016Q4YTD  2.291514e+08
# 7456686                                  FD2017Q4YTD  2.296544e+08
# 7460414                                  FD2014Q4YTD  2.377203e+08
# 7460415                                  FD2015Q4YTD  2.342217e+08
# 7460416                                  FD2016Q4YTD  2.291514e+08
# 7464071                                  FD2013Q4YTD  2.405548e+08
# 7464072                                  FD2014Q4YTD  2.377203e+08
# 7464073                                  FD2015Q4YTD  2.342217e+08
# 7466215  eol_PE10923---1410-K0020_STD_365_20131231_0  2.405548e+08
# 7466727  eol_PE10923---1410-K0020_STD_365_20141231_0  2.377203e+08
# 7467387  eol_PE10923---1410-K0020_STD_366_20121231_0  2.408812e+08
# 7469735  eol_PE10923---1310-K0019_STD_365_20111231_0  2.418114e+08
# 7470127  eol_PE10923---1310-K0019_STD_365_20131231_0  2.405548e+08
# 7470805  eol_PE10923---1310-K0019_STD_366_20121231_0  2.408812e+08
# 7473234  eol_PE10923---1210-K0027_STD_365_20101231_0  2.425025e+08
# 7473598  eol_PE10923---1210-K0027_STD_365_20111231_0  2.418114e+08
# 7474138  eol_PE10923---1210-K0027_STD_366_20121231_0  2.408812e+08
# 7476752  eol_PE10923---1110-K0022_STD_365_20091231_0  2.364160e+08
# 7477105  eol_PE10923---1110-K0022_STD_365_20101231_0  2.425025e+08
# 7477609  eol_PE10923---1110-K0022_STD_365_20111231_0  2.418114e+08
# 7479988  eol_PE10923---1010-K0021_STD_365_20091231_0  2.364160e+14
# 7480512  eol_PE10923---1010-K0021_STD_365_20101231_0  2.425025e+14
# 7481066  eol_PE10923---1010-K0021_STD_366_20081231_0  2.240534e+14

# %%
edgar[
    (edgar['security'] == 'Northern Trust Corp.') & 
    (edgar['name'] == 'Weighted Average Number Of Shares Outstanding Basic')
]
# Out:
#                      security  \
# 7452930  Northern Trust Corp.
# 7452931  Northern Trust Corp.
# 7452932  Northern Trust Corp.
# 7456687  Northern Trust Corp.
# 7456688  Northern Trust Corp.
# 7456689  Northern Trust Corp.
# 7460417  Northern Trust Corp.
# 7460418  Northern Trust Corp.
# 7460419  Northern Trust Corp.
# 7464074  Northern Trust Corp.
# 7464075  Northern Trust Corp.
# 7464076  Northern Trust Corp.
# 7466221  Northern Trust Corp.
# 7466775  Northern Trust Corp.
# 7467392  Northern Trust Corp.
# 7469744  Northern Trust Corp.
# 7470201  Northern Trust Corp.
# 7470815  Northern Trust Corp.
# 7473257  Northern Trust Corp.
# 7473620  Northern Trust Corp.
# 7474174  Northern Trust Corp.
# 7476734  Northern Trust Corp.
# 7477085  Northern Trust Corp.
# 7477572  Northern Trust Corp.
# 7479989  Northern Trust Corp.
# 7480513  Northern Trust Corp.
# 7481067  Northern Trust Corp.
#
#                                                       name value unit_ref  \
# 7452930  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7452931  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7452932  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7456687  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7456688  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7456689  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7460417  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7460418  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7460419  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7464074  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7464075  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7464076  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7466221  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7466775  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7467392  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7469744  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7470201  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7470815  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7473257  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7473620  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7474174  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7476734  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7477085  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7477572  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7479989  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7480513  Weighted Average Number Of Shares Outstanding ...   NaN   shares
# 7481067  Weighted Average Number Of Shares Outstanding ...   NaN   shares
#
#                                          context_ref        number
# 7452930                                  FD2016Q4YTD  2.275806e+08
# 7452931                                  FD2017Q4YTD  2.282577e+08
# 7452932                                  FD2018Q4YTD  2.231483e+08
# 7456687                                  FD2015Q4YTD  2.322798e+08
# 7456688                                  FD2016Q4YTD  2.275806e+08
# 7456689                                  FD2017Q4YTD  2.282577e+08
# 7460417                                  FD2014Q4YTD  2.358298e+08
# 7460418                                  FD2015Q4YTD  2.322798e+08
# 7460419                                  FD2016Q4YTD  2.275806e+08
# 7464074                                  FD2013Q4YTD  2.392653e+08
# 7464075                                  FD2014Q4YTD  2.358298e+08
# 7464076                                  FD2015Q4YTD  2.322798e+08
# 7466221  eol_PE10923---1410-K0020_STD_365_20131231_0  2.392653e+08
# 7466775  eol_PE10923---1410-K0020_STD_365_20141231_0  2.358298e+08
# 7467392  eol_PE10923---1410-K0020_STD_366_20121231_0  2.404178e+08
# 7469744  eol_PE10923---1310-K0019_STD_365_20111231_0  2.414013e+08
# 7470201  eol_PE10923---1310-K0019_STD_365_20131231_0  2.392653e+08
# 7470815  eol_PE10923---1310-K0019_STD_366_20121231_0  2.404178e+08
# 7473257  eol_PE10923---1210-K0027_STD_365_20101231_0  2.420288e+08
# 7473620  eol_PE10923---1210-K0027_STD_365_20111231_0  2.414013e+08
# 7474174  eol_PE10923---1210-K0027_STD_366_20121231_0  2.404178e+08
# 7476734  eol_PE10923---1110-K0022_STD_365_20091231_0  2.355119e+08
# 7477085  eol_PE10923---1110-K0022_STD_365_20101231_0  2.420288e+08
# 7477572  eol_PE10923---1110-K0022_STD_365_20111231_0  2.414013e+08
# 7479989  eol_PE10923---1010-K0021_STD_365_20091231_0  2.355119e+14
# 7480513  eol_PE10923---1010-K0021_STD_365_20101231_0  2.420288e+14
# 7481067  eol_PE10923---1010-K0021_STD_366_20081231_0  2.214464e+14

# %%
edgar[
    (edgar['security'] == 'Skyworks Solutions') & 
    (edgar['name'] == 'Entity Public Float')
]
# Out:
#                    security                 name value unit_ref  \
# 9333183  Skyworks Solutions  Entity Public Float   NaN      usd
# 9334217  Skyworks Solutions  Entity Public Float   NaN      usd
# 9335199  Skyworks Solutions  Entity Public Float   NaN      usd
# 9336236  Skyworks Solutions  Entity Public Float   NaN      usd
# 9338225  Skyworks Solutions  Entity Public Float   NaN      usd
# 9339130  Skyworks Solutions  Entity Public Float   NaN      usd
# 9340185  Skyworks Solutions  Entity Public Float   NaN      usd
# 9341312  Skyworks Solutions  Entity Public Float   NaN      usd
# 9341347  Skyworks Solutions  Entity Public Float   NaN      USD
#
#                    context_ref        number
# 9333183           I2018Q2float  1.819456e+10
# 9334217               FI2017Q2  1.802220e+10
# 9335199               FI2016Q2  1.481236e+10
# 9336236               FI2015Q2  1.837813e+10
# 9338225               FI2014Q2  6.963440e+09
# 9339130                I2013Q2  4.182674e+09
# 9340185                I2012Q2  5.196462e+09
# 9341312     I2011Q2PublicFloat  5.808023e+15
# 9341347  BalanceAsOf_02Apr2010  2.716066e+09

# %%
edgar[
    (edgar['security'] == 'U.S. Bancorp') & 
    (edgar['name'] == 'Share Based Compensation Arrangement By Share Based Payment Award Options Outstanding Number')
]
# Out:
#               security                                               name  \
# 10033839  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10033914  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10034148  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10035185  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10038664  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10038743  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10038985  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10040088  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10043655  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10043740  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10043976  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10045112  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10048759  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10048839  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10048936  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10050008  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10053965  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10054047  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10054163  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10055187  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10059303  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10059385  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10059489  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10060667  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10065092  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10065170  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10065313  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10066450  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10075699  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10075700  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10075701  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10075702  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10080632  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10080633  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10080634  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10080635  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
#
#          value unit_ref                                context_ref  \
# 10033839   NaN   shares  eol_PE11930---1810-K0018_STD_0_20151231_0
# 10033914   NaN   shares  eol_PE11930---1810-K0018_STD_0_20161231_0
# 10034148   NaN   shares  eol_PE11930---1810-K0018_STD_0_20171231_0
# 10035185   NaN   shares  eol_PE11930---1810-K0018_STD_0_20181231_0
# 10038664   NaN   shares  eol_PE11930---1710-K0011_STD_0_20141231_0
# 10038743   NaN   shares  eol_PE11930---1710-K0011_STD_0_20151231_0
# 10038985   NaN   shares  eol_PE11930---1710-K0011_STD_0_20161231_0
# 10040088   NaN   shares  eol_PE11930---1710-K0011_STD_0_20171231_0
# 10043655   NaN   shares  eol_PE11930---1610-K0011_STD_0_20131231_0
# 10043740   NaN   shares  eol_PE11930---1610-K0011_STD_0_20141231_0
# 10043976   NaN   shares  eol_PE11930---1610-K0011_STD_0_20151231_0
# 10045112   NaN   shares  eol_PE11930---1610-K0011_STD_0_20161231_0
# 10048759   NaN   shares  eol_PE11930---1510-K0012_STD_0_20121231_0
# 10048839   NaN   shares  eol_PE11930---1510-K0012_STD_0_20131231_0
# 10048936   NaN   shares  eol_PE11930---1510-K0012_STD_0_20141231_0
# 10050008   NaN   shares  eol_PE11930---1510-K0012_STD_0_20151231_0
# 10053965   NaN   shares  eol_PE11930---1410-K0009_STD_0_20111231_0
# 10054047   NaN   shares  eol_PE11930---1410-K0009_STD_0_20121231_0
# 10054163   NaN   shares  eol_PE11930---1410-K0009_STD_0_20131231_0
# 10055187   NaN   shares  eol_PE11930---1410-K0009_STD_0_20141231_0
# 10059303   NaN   shares  eol_PE11930---1310-K0013_STD_0_20101231_0
# 10059385   NaN   shares  eol_PE11930---1310-K0013_STD_0_20111231_0
# 10059489   NaN   shares  eol_PE11930---1310-K0013_STD_0_20121231_0
# 10060667   NaN   shares  eol_PE11930---1310-K0013_STD_0_20131231_0
# 10065092   NaN   shares  eol_PE11930---1210-K0008_STD_0_20091231_0
# 10065170   NaN   shares  eol_PE11930---1210-K0008_STD_0_20101231_0
# 10065313   NaN   shares  eol_PE11930---1210-K0008_STD_0_20111231_0
# 10066450   NaN   shares  eol_PE11930---1210-K0008_STD_0_20121231_0
# 10075699   NaN   Shares                      BalanceAsOf_31Dec2008
# 10075700   NaN   Shares                      BalanceAsOf_31Dec2009
# 10075701   NaN   Shares                      BalanceAsOf_31Dec2010
# 10075702   NaN   Shares                      BalanceAsOf_31Dec2011
# 10080632   NaN   Shares                      BalanceAsOf_31Dec2007
# 10080633   NaN   Shares                      BalanceAsOf_31Dec2008
# 10080634   NaN   Shares                      BalanceAsOf_31Dec2009
# 10080635   NaN   Shares                      BalanceAsOf_31Dec2010
#
#                 number
# 10033839  2.572571e+07
# 10033914  1.705924e+07
# 10034148  1.266847e+07
# 10035185  9.115010e+06
# 10038664  3.364920e+07
# 10038743  2.572571e+07
# 10038985  1.705924e+07
# 10040088  1.266847e+07
# 10043655  4.672476e+07
# 10043740  3.364920e+07
# 10043976  2.572571e+07
# 10045112  1.705924e+07
# 10048759  6.317192e+07
# 10048839  4.672476e+07
# 10048936  3.364920e+07
# 10050008  2.572571e+07
# 10053965  7.582394e+07
# 10054047  6.317192e+07
# 10054163  4.672476e+07
# 10055187  3.364920e+07
# 10059303  8.562270e+07
# 10059385  7.582394e+07
# 10059489  6.317192e+07
# 10060667  4.672476e+07
# 10065092  8.837947e+07
# 10065170  8.562270e+07
# 10065313  7.582394e+07
# 10066450  6.317192e+07
# 10075699  8.229301e+13
# 10075700  8.837947e+13
# 10075701  8.562270e+13
# 10075702  7.582394e+13
# 10080632  9.121146e+07
# 10080633  8.229301e+07
# 10080634  8.837947e+07
# 10080635  8.562270e+07

# %% [markdown]
# Noted that the numbers should be 500,000,000 and 250,000,000 respectively, from https://www.sec.gov/cgi-bin/viewer?action=view&cik=103682&accession_number=0001193125-13-082933&xbrl_type=v#.

# %%
edgar.loc[
    (edgar['security'] == 'U.S. Bancorp') &
    (edgar['name'] == 'Share Based Compensation Arrangement By Share Based Payment Award Options Outstanding Number') &
    (edgar['number'] > 1_000_000_000),
    'number'
] /= 1_000_000

# %%
edgar.loc[
    (edgar['number'] > 80_000_000_000_000) | 
    (edgar['number'] < -10_000_000_000_000), 
    'number'
] /= 1_000_000

# %% [markdown]
# ---

# %%
edgar[
    edgar['number'] > 50_000_000_000_000
]
# Out:
#                       security  \
# 2372091         Citigroup Inc.
# 2382324         Citigroup Inc.
# 2382399         Citigroup Inc.
# 2393044         Citigroup Inc.
# 2393063         Citigroup Inc.
# 2393122         Citigroup Inc.
# 2402928         Citigroup Inc.
# 2771907   The Cooper Companies
# 4289715    Fifth Third Bancorp
# 4809080    Goldman Sachs Group
# 4809638    Goldman Sachs Group
# 4813457    Goldman Sachs Group
# 4814013    Goldman Sachs Group
# 4817855    Goldman Sachs Group
# 4818398    Goldman Sachs Group
# 4818830    Goldman Sachs Group
# 4819421    Goldman Sachs Group
# 4823569    Goldman Sachs Group
# 4823572    Goldman Sachs Group
# 5790405   JPMorgan Chase & Co.
# 5799066   JPMorgan Chase & Co.
# 5799089   JPMorgan Chase & Co.
# 5808071   JPMorgan Chase & Co.
# 5808092   JPMorgan Chase & Co.
# 5808094   JPMorgan Chase & Co.
# 5827054   JPMorgan Chase & Co.
# 5827064   JPMorgan Chase & Co.
# 5827087   JPMorgan Chase & Co.
# 5827090   JPMorgan Chase & Co.
# 5836316   JPMorgan Chase & Co.
# 5836326   JPMorgan Chase & Co.
# 5836349   JPMorgan Chase & Co.
# 5836352   JPMorgan Chase & Co.
# 5840924   JPMorgan Chase & Co.
# 5840926   JPMorgan Chase & Co.
# 5840935   JPMorgan Chase & Co.
# 5840939   JPMorgan Chase & Co.
# 5854324   JPMorgan Chase & Co.
# 5854327   JPMorgan Chase & Co.
# 5854346   JPMorgan Chase & Co.
# 5854351   JPMorgan Chase & Co.
# 10075669          U.S. Bancorp
# 10075670          U.S. Bancorp
# 10075671          U.S. Bancorp
#
#                                                        name value  \
# 2372091                          Derivative Notional Amount   NaN
# 2382324                          Derivative Notional Amount   NaN
# 2382399                          Derivative Notional Amount   NaN
# 2393044                          Derivative Notional Amount   NaN
# 2393063                          Derivative Notional Amount   NaN
# 2393122                          Derivative Notional Amount   NaN
# 2402928                          Derivative Notional Amount   NaN
# 2771907   Share Based Compensation Arrangement By Share ...   NaN
# 4289715                  Exchange Of Preferred Stock Shares   NaN
# 4809080                          Derivative Notional Amount   NaN
# 4809638                          Derivative Notional Amount   NaN
# 4813457                          Derivative Notional Amount   NaN
# 4814013                          Derivative Notional Amount   NaN
# 4817855                          Derivative Notional Amount   NaN
# 4818398                          Derivative Notional Amount   NaN
# 4818830                          Derivative Notional Amount   NaN
# 4819421                          Derivative Notional Amount   NaN
# 4823569                          Derivative Notional Amount   NaN
# 4823572                          Derivative Notional Amount   NaN
# 5790405                          Derivative Notional Amount   NaN
# 5799066                          Derivative Notional Amount   NaN
# 5799089                          Derivative Notional Amount   NaN
# 5808071                          Derivative Notional Amount   NaN
# 5808092                          Derivative Notional Amount   NaN
# 5808094                          Derivative Notional Amount   NaN
# 5827054                          Derivative Notional Amount   NaN
# 5827064                          Derivative Notional Amount   NaN
# 5827087                          Derivative Notional Amount   NaN
# 5827090                          Derivative Notional Amount   NaN
# 5836316                          Derivative Notional Amount   NaN
# 5836326                          Derivative Notional Amount   NaN
# 5836349                          Derivative Notional Amount   NaN
# 5836352                          Derivative Notional Amount   NaN
# 5840924                      Notional Amount Of Derivatives   NaN
# 5840926                      Notional Amount Of Derivatives   NaN
# 5840935                      Notional Amount Of Derivatives   NaN
# 5840939                      Notional Amount Of Derivatives   NaN
# 5854324                      Notional Amount Of Derivatives   NaN
# 5854327                      Notional Amount Of Derivatives   NaN
# 5854346                      Notional Amount Of Derivatives   NaN
# 5854351                      Notional Amount Of Derivatives   NaN
# 10075669  Share Based Compensation Arrangement By Share ...   NaN
# 10075670  Share Based Compensation Arrangement By Share ...   NaN
# 10075671  Share Based Compensation Arrangement By Share ...   NaN
#
#              unit_ref                                        context_ref  \
# 2372091           usd  FI2014Q4_us-gaap_HedgingDesignationAxis_us-gaa...
# 2382324           usd  FI2013Q4_us-gaap_DerivativeInstrumentsGainLoss...
# 2382399           usd  FI2014Q4_us-gaap_DerivativeInstrumentsGainLoss...
# 2393044           USD  I2013_NondesignatedPrincipalAndProprietaryTran...
# 2393063           USD  I2013_NondesignatedPrincipalAndProprietaryTran...
# 2393122           USD  I2012_NondesignatedPrincipalAndProprietaryTran...
# 2402928           USD                     I2012_TradingDerivativesMember
# 2771907         Unit1                                   As_Of_10_31_2011
# 4289715        shares  eol_PE7793----1010-K0029_STD_365_20091231_0_41...
# 4809080   iso4217_USD          eol_PE11158---1510-K0020_STD_0_20141231_0
# 4809638   iso4217_USD  eol_PE11158---1510-K0020_STD_0_20141231_0_1636...
# 4813457   iso4217_USD          eol_PE11158---1510-K0020_STD_0_20141231_0
# 4814013   iso4217_USD  eol_PE11158---1510-K0020_STD_0_20141231_0_1636...
# 4817855   iso4217_USD          eol_PE11158---1410-K0009_STD_0_20131231_0
# 4818398   iso4217_USD  eol_PE11158---1410-K0009_STD_0_20131231_0_1270...
# 4818830   iso4217_USD          eol_PE11158---1410-K0009_STD_0_20141231_0
# 4819421   iso4217_USD  eol_PE11158---1410-K0009_STD_0_20141231_0_1270...
# 4823569           USD                              BalanceAsOf_31Dec2013
# 4823572           USD         BalanceAsOf_31Dec2013_Nondesignated_Member
# 5790405           usd                                           FI2015Q4
# 5799066           usd                                           FI2014Q4
# 5799089           usd                                           FI2015Q4
# 5808071           usd                                           FI2013Q4
# 5808092           usd  FI2013Q4_us-gaap_DerivativeInstrumentRiskAxis_...
# 5808094           usd                                           FI2014Q4
# 5827054           usd                                           FI2013Q4
# 5827064           usd  FI2013Q4_us-gaap_DerivativeInstrumentRiskAxis_...
# 5827087           usd                                           FI2012Q4
# 5827090           usd  FI2012Q4_us-gaap_DerivativeInstrumentRiskAxis_...
# 5836316           usd                                            I2012Q4
# 5836326           usd  I2012Q4_us-gaap_DerivativeInstrumentRiskAxis_u...
# 5836349           usd                                            I2011Q4
# 5836352           usd  I2011Q4_us-gaap_DerivativeInstrumentRiskAxis_u...
# 5840924           usd                                            I2011Q4
# 5840926           usd  I2010Q4_us-gaap_DerivativeInstrumentRiskAxis_u...
# 5840935           usd  I2011Q4_us-gaap_DerivativeInstrumentRiskAxis_u...
# 5840939           usd                                            I2010Q4
# 5854324           USD                              BalanceAsOf_31Dec2009
# 5854327           USD  BalanceAsOf_31Dec2009_Interest_Rate_Contract_M...
# 5854346           USD                              BalanceAsOf_31Dec2010
# 5854351           USD  BalanceAsOf_31Dec2010_Interest_Rate_Contract_M...
# 10075669       Shares                              BalanceAsOf_31Dec2009
# 10075670       Shares                              BalanceAsOf_31Dec2010
# 10075671       Shares                              BalanceAsOf_31Dec2011
#
#                 number
# 2372091   5.901671e+13
# 2382324   5.987163e+13
# 2382399   5.816791e+13
# 2393044   5.055927e+13
# 2393063   6.128901e+13
# 2393122   5.235818e+13
# 2402928   5.235818e+13
# 2771907   5.552037e+13
# 4289715   6.012112e+13
# 4809080   5.751079e+13
# 4809638   5.737465e+13
# 4813457   5.751079e+13
# 4814013   5.737465e+13
# 4817855   5.361894e+13
# 4818398   5.347643e+13
# 4818830   5.751079e+13
# 4819421   5.737465e+13
# 4823569   5.361894e+13
# 4823572   5.347643e+13
# 5790405   5.065900e+13
# 5799066   6.366200e+13
# 5799089   5.065900e+13
# 5808071   7.041300e+13
# 5808092   5.470500e+13
# 5808094   6.366200e+13
# 5827054   7.043000e+13
# 5827064   5.465000e+13
# 5827087   6.932800e+13
# 5827090   5.256200e+13
# 5836316   6.955000e+13
# 5836326   5.278400e+13
# 5836349   7.115600e+13
# 5836352   5.446000e+13
# 5840924   7.115600e+13
# 5840926   6.364000e+13
# 5840935   5.446000e+13
# 5840939   7.890500e+13
# 5854324   7.873300e+13
# 5854327   6.378600e+13
# 5854346   7.890500e+13
# 5854351   6.364000e+13
# 10075669  5.053805e+13
# 10075670  5.754206e+13
# 10075671  5.703933e+13

# %% [markdown]
# Citigroup Inc.
# - Noted the number makes sense at 61,289,007 million (61,289,007,000,000), from https://www.sec.gov/cgi-bin/viewer?action=view&cik=831001&accession_number=0001104659-14-015152&xbrl_type=v#.

# %%
edgar[
    (edgar['security'] == 'Fifth Third Bancorp') & 
    (edgar['name'] == 'Exchange Of Preferred Stock Shares')
]
# Out:
#                     security                                name value  \
# 4281397  Fifth Third Bancorp  Exchange Of Preferred Stock Shares   NaN
# 4285700  Fifth Third Bancorp  Exchange Of Preferred Stock Shares   NaN
# 4285711  Fifth Third Bancorp  Exchange Of Preferred Stock Shares   NaN
# 4285734  Fifth Third Bancorp  Exchange Of Preferred Stock Shares   NaN
# 4289715  Fifth Third Bancorp  Exchange Of Preferred Stock Shares   NaN
# 4289719  Fifth Third Bancorp  Exchange Of Preferred Stock Shares   NaN
#
#         unit_ref                                        context_ref  \
# 4281397   Shares  FROM_Jan01_2011_TO_Dec31_2011_us-gaap_Statemen...
# 4285700   Shares  FROM_Jan01_2009_TO_Dec31_2009_us-gaap_Statemen...
# 4285711   Shares  FROM_Jan01_2009_TO_Dec31_2009_us-gaap_Statemen...
# 4285734   Shares  FROM_Jan01_2011_TO_Dec31_2011_us-gaap_Statemen...
# 4289715   shares  eol_PE7793----1010-K0029_STD_365_20091231_0_41...
# 4289719   shares  eol_PE7793----1010-K0029_STD_365_20091231_0_41...
#
#                number
# 4281397 -1.363200e+05
# 4285700  6.012112e+07
# 4285711 -2.784900e+04
# 4285734 -1.363200e+05
# 4289715  6.012112e+13
# 4289719 -2.784900e+10

# %%
edgar.loc[
    (edgar['security'] == 'Fifth Third Bancorp') &
    (edgar['name'] == 'Exchange Of Preferred Stock Shares') &
    (
        (edgar['number'] > 100_000_000) |
        (edgar['number'] < -1_000_000)
    ),
    'number'
] /= 1_000_000

# %% [markdown]
# JPMorgan Chase & Co.
# - Noted the numbers makes sense, i.e. observation number 5,799,066 at 63,662 billion (63,662,000,000,000), from https://www.sec.gov/cgi-bin/viewer?action=view&cik=19617&accession_number=0000019617-15-000272&xbrl_type=v#.

# %%
edgar[
    (edgar['security'] == 'The Cooper Companies') & 
    (edgar['name'] == 'Share Based Compensation Arrangement By Share Based Payment Award Options Vested And Expected To Vest Exercisable Aggregate Intrinsic Value')
]
# Out:
#                      security  \
# 2761263  The Cooper Companies
# 2762719  The Cooper Companies
# 2764300  The Cooper Companies
# 2765853  The Cooper Companies
# 2767322  The Cooper Companies
# 2768712  The Cooper Companies
# 2770092  The Cooper Companies
# 2771907  The Cooper Companies
#
#                                                       name value unit_ref  \
# 2761263  Share Based Compensation Arrangement By Share ...   NaN      usd
# 2762719  Share Based Compensation Arrangement By Share ...   NaN      usd
# 2764300  Share Based Compensation Arrangement By Share ...   NaN      usd
# 2765853  Share Based Compensation Arrangement By Share ...   NaN      usd
# 2767322  Share Based Compensation Arrangement By Share ...   NaN      usd
# 2768712  Share Based Compensation Arrangement By Share ...   NaN      usd
# 2770092  Share Based Compensation Arrangement By Share ...   NaN      usd
# 2771907  Share Based Compensation Arrangement By Share ...   NaN    Unit1
#
#                                                context_ref        number
# 2761263  FI2018Q4_us-gaap_AwardTypeAxis_us-gaap_Employe...  4.974133e+07
# 2762719  FI2017Q4_us-gaap_AwardTypeAxis_us-gaap_Employe...  5.892960e+07
# 2764300  FI2016Q4_us-gaap_AwardTypeAxis_us-gaap_Employe...  4.740812e+07
# 2765853  FI2015Q4_us-gaap_AwardTypeAxis_us-gaap_Employe...  6.741732e+07
# 2767322  FI2014Q4_us-gaap_AwardTypeAxis_us-gaap_Employe...  1.042940e+08
# 2768712  I2013Q4_us-gaap_AwardTypeAxis_us-gaap_Employee...  8.881809e+07
# 2770092  I2012Q4_us-gaap_AwardTypeAxis_us-gaap_StockOpt...  7.455814e+07
# 2771907                                   As_Of_10_31_2011  5.552037e+13

# %%
edgar.loc[
    (edgar['security'] == 'The Cooper Companies') &
    (edgar['name'] == 'Share Based Compensation Arrangement By Share Based Payment Award Options Vested And Expected To Vest Exercisable Aggregate Intrinsic Value') &
    (edgar['number'] > 1_000_000_000),
    'number'
] /= 1_000_000

# %%
edgar[
    (edgar['security'] == 'U.S. Bancorp') & 
    (edgar['name'] == 'Share Based Compensation Arrangement By Share Based Payment Award Options Exercisable Number')
]
# Out:
#               security                                               name  \
# 10033912  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10034146  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10035183  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10038741  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10038983  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10040086  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10043729  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10043942  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10045059  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10048844  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10048947  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10050024  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10054042  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10054148  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10055166  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10059382  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10059484  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10060658  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10065174  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10065331  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10066473  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10075669  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10075670  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10075671  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10080599  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10080600  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
# 10080601  U.S. Bancorp  Share Based Compensation Arrangement By Share ...
#
#          value unit_ref                                context_ref  \
# 10033912   NaN   shares  eol_PE11930---1810-K0018_STD_0_20161231_0
# 10034146   NaN   shares  eol_PE11930---1810-K0018_STD_0_20171231_0
# 10035183   NaN   shares  eol_PE11930---1810-K0018_STD_0_20181231_0
# 10038741   NaN   shares  eol_PE11930---1710-K0011_STD_0_20151231_0
# 10038983   NaN   shares  eol_PE11930---1710-K0011_STD_0_20161231_0
# 10040086   NaN   shares  eol_PE11930---1710-K0011_STD_0_20171231_0
# 10043729   NaN   shares  eol_PE11930---1610-K0011_STD_0_20141231_0
# 10043942   NaN   shares  eol_PE11930---1610-K0011_STD_0_20151231_0
# 10045059   NaN   shares  eol_PE11930---1610-K0011_STD_0_20161231_0
# 10048844   NaN   shares  eol_PE11930---1510-K0012_STD_0_20131231_0
# 10048947   NaN   shares  eol_PE11930---1510-K0012_STD_0_20141231_0
# 10050024   NaN   shares  eol_PE11930---1510-K0012_STD_0_20151231_0
# 10054042   NaN   shares  eol_PE11930---1410-K0009_STD_0_20121231_0
# 10054148   NaN   shares  eol_PE11930---1410-K0009_STD_0_20131231_0
# 10055166   NaN   shares  eol_PE11930---1410-K0009_STD_0_20141231_0
# 10059382   NaN   shares  eol_PE11930---1310-K0013_STD_0_20111231_0
# 10059484   NaN   shares  eol_PE11930---1310-K0013_STD_0_20121231_0
# 10060658   NaN   shares  eol_PE11930---1310-K0013_STD_0_20131231_0
# 10065174   NaN   shares  eol_PE11930---1210-K0008_STD_0_20101231_0
# 10065331   NaN   shares  eol_PE11930---1210-K0008_STD_0_20111231_0
# 10066473   NaN   shares  eol_PE11930---1210-K0008_STD_0_20121231_0
# 10075669   NaN   Shares                      BalanceAsOf_31Dec2009
# 10075670   NaN   Shares                      BalanceAsOf_31Dec2010
# 10075671   NaN   Shares                      BalanceAsOf_31Dec2011
# 10080599   NaN   Shares                      BalanceAsOf_31Dec2008
# 10080600   NaN   Shares                      BalanceAsOf_31Dec2009
# 10080601   NaN   Shares                      BalanceAsOf_31Dec2010
#
#                 number
# 10033912  1.385614e+07
# 10034146  9.647937e+06
# 10035183  7.372036e+06
# 10038741  2.244610e+07
# 10038983  1.385614e+07
# 10040086  9.647937e+06
# 10043729  2.892326e+07
# 10043942  2.244610e+07
# 10045059  1.385614e+07
# 10048844  3.955600e+07
# 10048947  2.892326e+07
# 10050024  2.244610e+07
# 10054042  5.067165e+07
# 10054148  3.955600e+07
# 10055166  2.892326e+07
# 10059382  5.703933e+07
# 10059484  5.067165e+07
# 10060658  3.955600e+07
# 10065174  5.754206e+07
# 10065331  5.703933e+07
# 10066473  5.067165e+07
# 10075669  5.053805e+13
# 10075670  5.754206e+13
# 10075671  5.703933e+13
# 10080599  4.378780e+07
# 10080600  5.053805e+07
# 10080601  5.754206e+07

# %%
edgar.loc[
    (edgar['security'] == 'U.S. Bancorp') &
    (edgar['name'] == 'Share Based Compensation Arrangement By Share Based Payment Award Options Exercisable Number') &
    (edgar['number'] > 100_000_000),
    'number'
] /= 1_000_000

# %% [markdown]
# ---

# %%
edgar = edgar[
    (edgar['name'] == 'Defined Benefit Plan Fair Value Of Plan Assets') |
    (edgar['name'] == 'Real Estate And Accumulated Depreciation Initial Cost Of Buildings And Improvements') |
    (edgar['name'] == 'Real Estate And Accumulated Depreciation Carrying Amount Of Buildings And Improvements') |
    (edgar['name'] == 'Real Estate And Accumulated Depreciation Initial Cost Of Land') |
    (edgar['name'] == 'Real Estate And Accumulated Depreciation Carrying Amount Of Land') |
    (edgar['name'] == 'Real Estate Accumulated Depreciation') |
    (edgar['name'] == 'Stockholders Equity Including Portion Attributable To Noncontrolling Interest') |
    (edgar['name'] == 'Real Estate Gross At Carrying Value') |
    (edgar['name'] == 'Revenues') |
    (edgar['name'] == 'Net Income Loss') |
    (edgar['name'] == 'Operating Income Loss') |
    (edgar['name'] == 'Stockholders Equity') |
    (edgar['name'] == 'Sales Revenue Net') |
    (edgar['name'] == 'Real Estate And Accumulated Depreciation Life Used For Depreciation1') |
    (edgar['name'] == 'Debt Instrument Interest Rate Stated Percentage') |
    (edgar['name'] == 'Assets') |
    (edgar['name'] == 'Profit Loss') |
    (edgar['name'] == 'Goodwill') |
    (edgar['name'] == 'Income Tax Expense Benefit') |
    (edgar['name'] == 'Earnings Per Share Diluted') |
    (edgar['name'] == 'Earnings Per Share Basic') |
    (edgar['name'] == 'Real Estate And Accumulated Depreciation Costs Capitalized Subsequent To Acquisition Carrying Costs') |
    (edgar['name'] == 'Long Term Debt') |
    (edgar['name'] == 'Available For Sale Securities') |
    (edgar['name'] == 'Real Estate And Accumulated Depreciation Carrying Amount Of Land And Buildings And Improvements') |
    (edgar['name'] == 'Accumulated Other Comprehensive Income Loss Net Of Tax') |
    (edgar['name'] == 'Cash And Cash Equivalents At Carrying Value') |
    (edgar['name'] == 'Property Plant And Equipment Gross') |
    (edgar['name'] == 'Other Comprehensive Income Loss Net Of Tax') |
    (edgar['name'] == 'Property Plant And Equipment Net') |
    (edgar['name'] == 'Real Estate And Accumulated Depreciation Costs Capitalized Subsequent To Acquisition Improvements') |
    (edgar['name'] == 'Depreciation Depletion And Amortization') |
    (edgar['name'] == 'Debt Instrument Face Amount') |
    (edgar['name'] == 'Finite Lived Intangible Assets Accumulated Amortization') |
    (edgar['name'] == 'Derivative Fair Value Of Derivative Asset') |
    (edgar['name'] == 'Derivative Fair Value Of Derivative Liability') |
    (edgar['name'] == 'Allocated Share Based Compensation Expense') |
    (edgar['name'] == 'Real Estate And Accumulated Depreciation Accumulated Depreciation') |
    (edgar['name'] == 'Finite Lived Intangible Assets Gross') |
    (edgar['name'] == 'Interest Expense') |
    (edgar['name'] == 'Payments To Acquire Property Plant And Equipment') |
    (edgar['name'] == 'Debt Instrument Carrying Amount') |
    (edgar['name'] == 'Income Loss From Continuing Operations Before Income Taxes Minority Interest And Income Loss From Equity Method Investments') |
    (edgar['name'] == 'Defined Benefit Plan Benefit Obligation') |
    (edgar['name'] == 'Derivative Notional Amount') |
    (edgar['name'] == 'Valuation Allowances And Reserves Balance') |
    (edgar['name'] == 'Gross Profit') |
    (edgar['name'] == 'Income Loss From Continuing Operations Before Income Taxes Extraordinary Items Noncontrolling Interest') |
    (edgar['name'] == 'Defined Benefit Plan Net Periodic Benefit Cost') |
    (edgar['name'] == 'Income Loss From Equity Method Investments') |
    (edgar['name'] == 'Comprehensive Income Net Of Tax') |
    (edgar['name'] == 'Net Cash Provided By Used In Operating Activities') |
    (edgar['name'] == 'Sales Revenue Goods Net') |
    (edgar['name'] == 'Net Cash Provided By Used In Financing Activities') |
    (edgar['name'] == 'Defined Benefit Plan Interest Cost') |
    (edgar['name'] == 'Restructuring Charges') |
    (edgar['name'] == 'Cash And Cash Equivalents Period Increase Decrease') |
    (edgar['name'] == 'Net Cash Provided By Used In Investing Activities') |
    (edgar['name'] == 'Defined Benefit Plan Weighted Average Asset Allocations') |
    (edgar['name'] == 'Fair Value Measurement With Unobservable Inputs Reconciliation Recurring Basis Asset Value') 
]

# %% [markdown]
# ---

# %%
ax = edgar[
    (edgar['name'] != 'Derivative Notional Amount')
].boxplot(
    column='number', 
    by='name',
    vert=False,
    figsize=(20, 25)
)
ax.set_title('Distribution By Names', fontweight='bold')
ax.set_xlabel('');

# %%
edgar[
    (edgar['name'] == 'Real Estate Gross At Carrying Value') &
    (edgar['number'] > 500_000_000_000)
]
# Out:
# Empty DataFrame
# Columns: [security, name, value, unit_ref, context_ref, number]
# Index: []

# %% [markdown]
# Noted that numbers should be 8,882,341,499 (`6041212`), 7,818,916,120 (`6041213`), and 8,592,760,219 (`6041237` and `6041207`) respectively, from https://www.sec.gov/cgi-bin/viewer?action=view&cik=879101&accession_number=0001398432-11-000206&xbrl_type=v#.

# %%
edgar[
    (edgar['security'] == 'Apache Corporation') &
    (edgar['name'] == 'Allocated Share Based Compensation Expense')
]
# Out:
#                    security                                        name value  \
# 1019316  Apache Corporation  Allocated Share Based Compensation Expense   NaN
# 1019317  Apache Corporation  Allocated Share Based Compensation Expense   NaN
# 1019318  Apache Corporation  Allocated Share Based Compensation Expense   NaN
# 1019319  Apache Corporation  Allocated Share Based Compensation Expense   NaN
# 1019320  Apache Corporation  Allocated Share Based Compensation Expense   NaN
# ...                     ...                                         ...   ...
# 1049272  Apache Corporation  Allocated Share Based Compensation Expense   NaN
# 1049273  Apache Corporation  Allocated Share Based Compensation Expense   NaN
# 1049274  Apache Corporation  Allocated Share Based Compensation Expense   NaN
# 1049275  Apache Corporation  Allocated Share Based Compensation Expense   NaN
# 1049276  Apache Corporation  Allocated Share Based Compensation Expense   NaN
#
#         unit_ref                                        context_ref  \
# 1019316      usd                                        FD2016Q4YTD
# 1019317      usd  FD2016Q4YTD_us-gaap_AwardTypeAxis_apa_Conditio...
# 1019318      usd  FD2016Q4YTD_us-gaap_AwardTypeAxis_us-gaap_Rest...
# 1019319      usd                                        FD2017Q4YTD
# 1019320      usd  FD2017Q4YTD_us-gaap_AwardTypeAxis_apa_Conditio...
# ...          ...                                                ...
# 1049272      USD  TwelveMonthsEnded_31Dec2010_General_And_Admini...
# 1049273      USD  TwelveMonthsEnded_31Dec2010_Restricted_Stock_M...
# 1049274      USD  TwelveMonthsEnded_31Dec2010_Share_Appreciation...
# 1049275      USD  TwelveMonthsEnded_31Dec2010_Share_Appreciation...
# 1049276      USD  TwelveMonthsEnded_31Dec2010_Lease_Operating_Ex...
#
#               number
# 1019316  131000000.0
# 1019317   14000000.0
# 1019318  113000000.0
# 1019319  142000000.0
# 1019320   23000000.0
# ...              ...
# 1049272   98000000.0
# 1049273   73000000.0
# 1049274   49000000.0
# 1049275   27000000.0
# 1049276   66000000.0
#
# [157 rows x 6 columns]

# %%
edgar[
    (edgar['name'] == 'Real Estate And Accumulated Depreciation Costs Capitalized Subsequent To Acquisition Improvements') &
    (edgar['number'] > 500_000_000_000)
]
# Out:
# Empty DataFrame
# Columns: [security, name, value, unit_ref, context_ref, number]
# Index: []

# %%
edgar[
    (edgar['name'] == 'Real Estate And Accumulated Depreciation Carrying Amount Of Land And Buildings And Improvements') &
    (edgar['number'] > 500_000_000_000)
]
# Out:
# Empty DataFrame
# Columns: [security, name, value, unit_ref, context_ref, number]
# Index: []

# %%
edgar[
    (edgar['name'] == 'Real Estate And Accumulated Depreciation Carrying Amount Of Buildings And Improvements') &
    (edgar['number'] > 500_000_000_000)
]
# Out:
# Empty DataFrame
# Columns: [security, name, value, unit_ref, context_ref, number]
# Index: []

# %%
edgar[
    (edgar['name'] == 'Real Estate And Accumulated Depreciation Carrying Amount Of Land') &
    (edgar['number'] > 500_000_000_000)
]
# Out:
# Empty DataFrame
# Columns: [security, name, value, unit_ref, context_ref, number]
# Index: []

# %%
edgar[
    (edgar['name'] == 'Real Estate And Accumulated Depreciation Accumulated Depreciation') &
    (edgar['number'] > 500_000_000_000)
]
# Out:
# Empty DataFrame
# Columns: [security, name, value, unit_ref, context_ref, number]
# Index: []

# %%
edgar.loc[
    (edgar['security'] == 'Kimco Realty') & 
    (edgar['name'] == 'Real Estate And Accumulated Depreciation Costs Capitalized Subsequent To Acquisition Improvements') &
    (edgar['number'] > 500_000_000_000),
    'number'
] /= 1_000

# %%
edgar.loc[
    (edgar['security'] == 'Kimco Realty') & 
    (edgar['name'] == 'Real Estate Gross At Carrying Value') &
    (edgar['number'] > 500_000_000_000),
    'number'
] /= 1_000

# %%
edgar.loc[
    (edgar['security'] == 'Kimco Realty') & 
    (edgar['name'] == 'Real Estate And Accumulated Depreciation Carrying Amount Of Land And Buildings And Improvements') &
    (edgar['number'] > 500_000_000_000),
    'number'
] /= 1_000

# %%
edgar.loc[
    (edgar['security'] == 'Kimco Realty') & 
    (edgar['name'] == 'Real Estate And Accumulated Depreciation Carrying Amount Of Buildings And Improvements') &
    (edgar['number'] > 500_000_000_000),
    'number'
] /= 1_000

# %%
edgar.loc[
    (edgar['security'] == 'Kimco Realty') & 
    (edgar['name'] == 'Real Estate And Accumulated Depreciation Carrying Amount Of Land') &
    (edgar['number'] > 500_000_000_000),
    'number'
] /= 1_000

# %%
edgar.loc[
    (edgar['security'] == 'Kimco Realty') & 
    (edgar['name'] == 'Real Estate And Accumulated Depreciation Accumulated Depreciation') &
    (edgar['number'] > 500_000_000_000),
    'number'
] /= 1_000

# %%
edgar.loc[
    (edgar['security'] == 'Kimco Realty') & 
    (edgar['name'] == 'Real Estate Accumulated Depreciation') &
    (edgar['number'] > 500_000_000_000),
    'number'
] /= 1_000

# %%
edgar[
    (edgar['name'] == 'Derivative Fair Value Of Derivative Liability') &
    (edgar['number'] > 4_000_000_000_000)
]
# Out:
#                      security                                           name  \
# 1417590  Bank of America Corp  Derivative Fair Value Of Derivative Liability
# 1417591  Bank of America Corp  Derivative Fair Value Of Derivative Liability
# 1426620  Bank of America Corp  Derivative Fair Value Of Derivative Liability
# 1426626  Bank of America Corp  Derivative Fair Value Of Derivative Liability
#
#         value unit_ref                                        context_ref  \
# 1417590   NaN      usd  FI2013Q4_us-gaap_DerivativeByNatureAxis_bac_Cr...
# 1417591   NaN      usd  FI2013Q4_us-gaap_DerivativeByNatureAxis_bac_Cr...
# 1426620   NaN      usd  I2012Q4_us-gaap_DerivativeByNatureAxis_bac_Cre...
# 1426626   NaN      usd  I2012Q4_us-gaap_DerivativeByNatureAxis_bac_Cre...
#
#                number
# 1417590  7.284000e+12
# 1417591  5.330000e+12
# 1426620  4.306000e+12
# 1426626  6.322000e+12

# %% [markdown]
# Noted that numbers should be 7,284 million or 7,284,000,000 (`1417590`), 5,330 million or 5,330,000,000 (`1417591`), 4,306 million or 4,306,000,000 (`1426620`), and 6,322 million or 6,322,000,000 (`1426626`) respectively, from https://www.sec.gov/cgi-bin/viewer?action=view&cik=70858&accession_number=0000070858-14-000012&xbrl_type=v#.

# %%
edgar[
    (edgar['security'] == 'Bank of America Corp') & 
    (edgar['name'] == 'Derivative Fair Value Of Derivative Liability') &
    (edgar['number'] > 1_000_000_000_000)
]
# Out:
#                      security                                           name  \
# 1417590  Bank of America Corp  Derivative Fair Value Of Derivative Liability
# 1417591  Bank of America Corp  Derivative Fair Value Of Derivative Liability
# 1417592  Bank of America Corp  Derivative Fair Value Of Derivative Liability
# 1417610  Bank of America Corp  Derivative Fair Value Of Derivative Liability
# 1417612  Bank of America Corp  Derivative Fair Value Of Derivative Liability
# 1426620  Bank of America Corp  Derivative Fair Value Of Derivative Liability
# 1426624  Bank of America Corp  Derivative Fair Value Of Derivative Liability
# 1426626  Bank of America Corp  Derivative Fair Value Of Derivative Liability
# 1426643  Bank of America Corp  Derivative Fair Value Of Derivative Liability
# 1426650  Bank of America Corp  Derivative Fair Value Of Derivative Liability
# 1426655  Bank of America Corp  Derivative Fair Value Of Derivative Liability
# 1426669  Bank of America Corp  Derivative Fair Value Of Derivative Liability
# 1434964  Bank of America Corp  Derivative Fair Value Of Derivative Liability
# 1434969  Bank of America Corp  Derivative Fair Value Of Derivative Liability
# 1434990  Bank of America Corp  Derivative Fair Value Of Derivative Liability
# 1434998  Bank of America Corp  Derivative Fair Value Of Derivative Liability
# 1445523  Bank of America Corp  Derivative Fair Value Of Derivative Liability
# 1445540  Bank of America Corp  Derivative Fair Value Of Derivative Liability
# 1445541  Bank of America Corp  Derivative Fair Value Of Derivative Liability
# 1445546  Bank of America Corp  Derivative Fair Value Of Derivative Liability
#
#         value unit_ref                                        context_ref  \
# 1417590   NaN      usd  FI2013Q4_us-gaap_DerivativeByNatureAxis_bac_Cr...
# 1417591   NaN      usd  FI2013Q4_us-gaap_DerivativeByNatureAxis_bac_Cr...
# 1417592   NaN      usd  FI2013Q4_us-gaap_DerivativeByNatureAxis_bac_Cr...
# 1417610   NaN      usd                                           FI2012Q4
# 1417612   NaN      usd  FI2012Q4_us-gaap_DerivativeByNatureAxis_us-gaa...
# 1426620   NaN      usd  I2012Q4_us-gaap_DerivativeByNatureAxis_bac_Cre...
# 1426624   NaN      usd  I2012Q4_us-gaap_DerivativeByNatureAxis_bac_Cre...
# 1426626   NaN      usd  I2012Q4_us-gaap_DerivativeByNatureAxis_bac_Cre...
# 1426643   NaN      usd  I2011Q4_us-gaap_DerivativeByNatureAxis_us-gaap...
# 1426650   NaN      usd                                            I2011Q4
# 1426655   NaN      usd  I2012Q4_us-gaap_DerivativeByNatureAxis_us-gaap...
# 1426669   NaN      usd                                            I2012Q4
# 1434964   NaN      usd                                            I2010Q4
# 1434969   NaN      usd  I2010Q4_us-gaap_DerivativeByNatureAxis_us-gaap...
# 1434990   NaN      usd  I2011Q4_us-gaap_DerivativeByNatureAxis_us-gaap...
# 1434998   NaN      usd                                            I2011Q4
# 1445523   NaN      USD                              BalanceAsOf_31Dec2009
# 1445540   NaN      USD  BalanceAsOf_31Dec2009_Interest_Rate_Contract_M...
# 1445541   NaN      USD                              BalanceAsOf_31Dec2010
# 1445546   NaN      USD  BalanceAsOf_31Dec2010_Interest_Rate_Contract_M...
#
#                number
# 1417590  7.284000e+12
# 1417591  5.330000e+12
# 1417592  1.954000e+12
# 1417610  1.364800e+12
# 1417612  1.067300e+12
# 1426620  4.306000e+12
# 1426624  2.016000e+12
# 1426626  6.322000e+12
# 1426643  1.485300e+12
# 1426650  1.861300e+12
# 1426655  1.067300e+12
# 1426669  1.364800e+12
# 1434964  1.505800e+12
# 1434969  1.190100e+12
# 1434990  1.485300e+12
# 1434998  1.861300e+12
# 1445523  1.461600e+12
# 1445540  1.105800e+12
# 1445541  1.505800e+12
# 1445546  1.190100e+12

# %%
edgar.loc[
    [1417590, 1417591, 1417592, 1426620, 1426624, 1426626],
    'number'
] /= 1_000

# %%
edgar[
    (edgar['name'] == 'Assets') &
    (edgar['number'] > 4_000_000_000_000)
]
# Out:
#                  security    name value unit_ref  \
# 4325340  FirstEnergy Corp  Assets   NaN      usd
# 4325341  FirstEnergy Corp  Assets   NaN      usd
#
#                                                context_ref        number
# 4325340  I2010Q4_dei_LegalEntityAxis_fe_CeiMember_us-ga...  4.354128e+12
# 4325341  I2010Q4_dei_LegalEntityAxis_fe_CeiMember_us-ga...  4.303849e+12

# %% [markdown]
# Noted that number should be 4,354,128,000 (`4325340`), from https://www.sec.gov/cgi-bin/viewer?action=view&cik=1031296&accession_number=0001031296-12-000012&xbrl_type=v#.

# %%
edgar[
    (edgar['security'] == 'FirstEnergy Corp') & 
    (edgar['name'] == 'Assets') &
    (edgar['number'] > 500_000_000_000)
]
# Out:
# Empty DataFrame
# Columns: [security, name, value, unit_ref, context_ref, number]
# Index: []

# %%
edgar[
    (edgar['security'] == 'FirstEnergy Corp') & 
    (edgar['name'] == 'Property Plant And Equipment Gross') &
    (edgar['number'] > 500_000_000_000)
]
# Out:
#                  security                                name value unit_ref  \
# 4333070  FirstEnergy Corp  Property Plant And Equipment Gross   NaN      usd
# 4333072  FirstEnergy Corp  Property Plant And Equipment Gross   NaN      usd
#
#                                                context_ref        number
# 4333070  I2010Q4_dei_LegalEntityAxis_fe_TeMember_us-gaa...  9.624280e+11
# 4333072  I2010Q4_dei_LegalEntityAxis_fe_TeMember_us-gaa...  9.472030e+11

# %%
edgar.loc[
    (edgar['security'] == 'FirstEnergy Corp') & 
    (edgar['name'] == 'Assets') &
    (edgar['number'] > 500_000_000_000),
    'number'
] /= 1_000

# %%
edgar.loc[
    (edgar['security'] == 'FirstEnergy Corp') & 
    (edgar['name'] == 'Property Plant And Equipment Gross') &
    (edgar['number'] > 500_000_000_000),
    'number'
] /= 1_000

# %%
edgar[
    (edgar['name'] == 'Assets') &
    (edgar['number'] < -1_000_000_000_000)
]
# Out:
#                   security    name value unit_ref  \
# 4166019  Exxon Mobil Corp.  Assets   NaN   Unit12
# 4166031  Exxon Mobil Corp.  Assets   NaN   Unit12
# 4168754  Exxon Mobil Corp.  Assets   NaN   Unit12
# 4168760  Exxon Mobil Corp.  Assets   NaN   Unit12
# 4171796  Exxon Mobil Corp.  Assets   NaN   Unit12
# 4171802  Exxon Mobil Corp.  Assets   NaN   Unit12
# 4630039   General Electric  Assets   NaN      usd
# 4630057   General Electric  Assets   NaN      usd
# 4635131   General Electric  Assets   NaN      usd
# 4635148   General Electric  Assets   NaN      usd
# 4642762   General Electric  Assets   NaN      USD
# 4642866   General Electric  Assets   NaN      USD
#
#                                                context_ref        number
# 4166019  As_Of_12_31_2010_dei_LegalEntityAxis_us-gaap_C... -1.223592e+12
# 4166031  As_Of_12_31_2011_dei_LegalEntityAxis_us-gaap_C... -1.267076e+12
# 4168754                                  As_Of_12_31_20092 -1.072666e+12
# 4168760                                  As_Of_12_31_20102 -1.223592e+12
# 4171796                                  As_Of_12_31_20092 -1.072666e+12
# 4171802                                  As_Of_12_31_20102 -1.223592e+12
# 4630039  FI2017Q4_srt_ConsolidationItemsAxis_ge_Elimina... -1.421948e+12
# 4630057  FI2018Q4_srt_ConsolidationItemsAxis_ge_Elimina... -1.227850e+12
# 4635131  FI2016Q4_us-gaap_ConsolidationItemsAxis_ge_Eli... -1.112372e+12
# 4635148  FI2017Q4_us-gaap_ConsolidationItemsAxis_ge_Eli... -1.424806e+12
# 4642762  AS_OF_Dec31_2016_Entity_0000040545_us-gaap_Gua... -1.112372e+12
# 4642866  AS_OF_Dec31_2015_Entity_0000040545_us-gaap_Gua... -1.086754e+12

# %% [markdown]
# ---

# %%
edgar = pd.pivot(edgar, columns='name')
edgar.dropna(axis=1, how='all', inplace=True)
edgar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2534712 entries, 18 to 11241931
# Columns: 239 entries, ('security', 'Accumulated Other Comprehensive Income Loss Net Of Tax') to ('number', 'Valuation Allowances And Reserves Balance')
# dtypes: float64(59), object(180)
# memory usage: 4.5+ GB

# %% [markdown]
# ---
