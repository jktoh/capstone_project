# %% [markdown]
# # Preprocessing And Feature Engineering
# ---

# %% [markdown]
# ## Import Library

# %%
# Basic library
import pandas as pd

# Plotting libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /Users/junkai/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Load Cleaned Data

# %% [markdown]
# Load `clean.csv`, `sp500.csv`, `sp1000.csv` and `sp400.csv` from `data` folder into a pandas DataFrame.

# %%
df = pd.read_csv('../data/clean.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4933 entries, 0 to 4932
# Data columns (total 43 columns):
#  #   Column                                                                            Non-Null Count  Dtype
# ---  ------                                                                            --------------  -----
#  0   security                                                                          4933 non-null   object
#  1   year                                                                              4933 non-null   float64
#  2   Cash And Cash Equivalents At Carrying Value                                       4933 non-null   float64
#  3   Income Tax Expense Benefit                                                        4933 non-null   float64
#  4   Stockholders Equity                                                               4933 non-null   float64
#  5   Weighted Average Number Of Shares Outstanding Basic                               4933 non-null   float64
#  6   Assets                                                                            4933 non-null   float64
#  7   Unrecognized Tax Benefits                                                         4933 non-null   float64
#  8   Earnings Per Share Basic                                                          4933 non-null   float64
#  9   Net Income Loss                                                                   4933 non-null   float64
#  10  Deferred Income Tax Expense Benefit                                               4933 non-null   float64
#  11  Accumulated Other Comprehensive Income Loss Net Of Tax                            4933 non-null   float64
#  12  Net Cash Provided By Used In Investing Activities                                 4933 non-null   float64
#  13  Net Cash Provided By Used In Financing Activities                                 4933 non-null   float64
#  14  Current Federal Tax Expense Benefit                                               4933 non-null   float64
#  15  Net Cash Provided By Used In Operating Activities                                 4933 non-null   float64
#  16  Comprehensive Income Net Of Tax                                                   4933 non-null   float64
#  17  Retained Earnings Accumulated Deficit                                             4933 non-null   float64
#  18  Cash And Cash Equivalents Period Increase Decrease                                4933 non-null   float64
#  19  Share Based Compensation                                                          4933 non-null   float64
#  20  Current State And Local Tax Expense Benefit                                       4933 non-null   float64
#  21  Goodwill                                                                          4933 non-null   float64
#  22  Property Plant And Equipment Net                                                  4933 non-null   float64
#  23  Deferred Federal Income Tax Expense Benefit                                       4933 non-null   float64
#  24  Common Stock Shares Authorized                                                    4933 non-null   float64
#  25  Operating Income Loss                                                             4933 non-null   float64
#  26  Deferred State And Local Income Tax Expense Benefit                               4933 non-null   float64
#  27  Accumulated Depreciation Depletion And Amortization Property Plant And Equipment  4933 non-null   float64
#  28  Current Income Tax Expense Benefit                                                4933 non-null   float64
#  29  Common Stock Value                                                                4933 non-null   float64
#  30  Common Stock Par Or Stated Value Per Share                                        4933 non-null   float64
#  31  Common Stock Shares Issued                                                        4933 non-null   float64
#  32  Interest Expense                                                                  4933 non-null   float64
#  33  Payments For Repurchase Of Common Stock                                           4933 non-null   float64
#  34  Property Plant And Equipment Gross                                                4933 non-null   float64
#  35  Document Period End Date                                                          4933 non-null   object
#  36  Entity Well Known Seasoned Issuer                                                 4933 non-null   object
#  37  Amendment Flag                                                                    4933 non-null   bool
#  38  Document Fiscal Period Focus                                                      4933 non-null   object
#  39  Entity Filer Category                                                             4933 non-null   object
#  40  Document Type                                                                     4933 non-null   object
#  41  Entity Voluntary Filers                                                           4933 non-null   object
#  42  Entity Current Reporting Status                                                   4933 non-null   object
# dtypes: bool(1), float64(34), object(8)
# memory usage: 1.6+ MB

# %%
df.drop(columns='Document Period End Date', inplace=True)

# %%
sp500 = pd.read_csv('../data/sp500.csv')
sp500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ticker    505 non-null    object
#  1   security  505 non-null    object
#  2   sector    505 non-null    object
#  3   cik       505 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 15.9+ KB

# %%
sp1000 = pd.read_csv('../data/sp1000.csv')
sp1000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ticker    1000 non-null   object
#  1   security  1000 non-null   object
#  2   sector    999 non-null    object
#  3   cik       999 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 31.4+ KB

# %%
sp400 = pd.read_csv('../data/sp400.csv')
sp400.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ticker    400 non-null    object
#  1   security  400 non-null    object
# dtypes: object(2)
# memory usage: 6.4+ KB

# %% [markdown]
# ---

# %%
target = 'cap'

# %%
sp400.drop(columns='security', inplace=True)
sp500[target] = 'large-cap'
sp400[target] = 'mid-cap'

# %%
sp1000 = pd.merge(sp1000, sp400, on='ticker', how='left')
sp1000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ticker    1000 non-null   object
#  1   security  1000 non-null   object
#  2   sector    999 non-null    object
#  3   cik       999 non-null    float64
#  4   cap       373 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 46.9+ KB

# %%
sp1500 = pd.concat((sp500, sp1000)).reset_index(drop=True)
sp1500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1505 entries, 0 to 1504
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ticker    1505 non-null   object
#  1   security  1505 non-null   object
#  2   sector    1504 non-null   object
#  3   cik       1504 non-null   float64
#  4   cap       878 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 58.9+ KB

# %%
sp1500.drop(columns=['ticker', 'cik'], inplace=True)
sp1500[target] = sp1500[target].fillna('small-cap')
sp1500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1505 entries, 0 to 1504
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   security  1505 non-null   object
#  1   sector    1504 non-null   object
#  2   cap       1505 non-null   object
# dtypes: object(3)
# memory usage: 35.4+ KB

# %% [markdown]
# ---

# %%
df = pd.merge(df, sp1500, on='security')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4969 entries, 0 to 4968
# Data columns (total 44 columns):
#  #   Column                                                                            Non-Null Count  Dtype
# ---  ------                                                                            --------------  -----
#  0   security                                                                          4969 non-null   object
#  1   year                                                                              4969 non-null   float64
#  2   Cash And Cash Equivalents At Carrying Value                                       4969 non-null   float64
#  3   Income Tax Expense Benefit                                                        4969 non-null   float64
#  4   Stockholders Equity                                                               4969 non-null   float64
#  5   Weighted Average Number Of Shares Outstanding Basic                               4969 non-null   float64
#  6   Assets                                                                            4969 non-null   float64
#  7   Unrecognized Tax Benefits                                                         4969 non-null   float64
#  8   Earnings Per Share Basic                                                          4969 non-null   float64
#  9   Net Income Loss                                                                   4969 non-null   float64
#  10  Deferred Income Tax Expense Benefit                                               4969 non-null   float64
#  11  Accumulated Other Comprehensive Income Loss Net Of Tax                            4969 non-null   float64
#  12  Net Cash Provided By Used In Investing Activities                                 4969 non-null   float64
#  13  Net Cash Provided By Used In Financing Activities                                 4969 non-null   float64
#  14  Current Federal Tax Expense Benefit                                               4969 non-null   float64
#  15  Net Cash Provided By Used In Operating Activities                                 4969 non-null   float64
#  16  Comprehensive Income Net Of Tax                                                   4969 non-null   float64
#  17  Retained Earnings Accumulated Deficit                                             4969 non-null   float64
#  18  Cash And Cash Equivalents Period Increase Decrease                                4969 non-null   float64
#  19  Share Based Compensation                                                          4969 non-null   float64
#  20  Current State And Local Tax Expense Benefit                                       4969 non-null   float64
#  21  Goodwill                                                                          4969 non-null   float64
#  22  Property Plant And Equipment Net                                                  4969 non-null   float64
#  23  Deferred Federal Income Tax Expense Benefit                                       4969 non-null   float64
#  24  Common Stock Shares Authorized                                                    4969 non-null   float64
#  25  Operating Income Loss                                                             4969 non-null   float64
#  26  Deferred State And Local Income Tax Expense Benefit                               4969 non-null   float64
#  27  Accumulated Depreciation Depletion And Amortization Property Plant And Equipment  4969 non-null   float64
#  28  Current Income Tax Expense Benefit                                                4969 non-null   float64
#  29  Common Stock Value                                                                4969 non-null   float64
#  30  Common Stock Par Or Stated Value Per Share                                        4969 non-null   float64
#  31  Common Stock Shares Issued                                                        4969 non-null   float64
#  32  Interest Expense                                                                  4969 non-null   float64
#  33  Payments For Repurchase Of Common Stock                                           4969 non-null   float64
#  34  Property Plant And Equipment Gross                                                4969 non-null   float64
#  35  Entity Well Known Seasoned Issuer                                                 4969 non-null   object
#  36  Amendment Flag                                                                    4969 non-null   bool
#  37  Document Fiscal Period Focus                                                      4969 non-null   object
#  38  Entity Filer Category                                                             4969 non-null   object
#  39  Document Type                                                                     4969 non-null   object
#  40  Entity Voluntary Filers                                                           4969 non-null   object
#  41  Entity Current Reporting Status                                                   4969 non-null   object
#  42  sector                                                                            4969 non-null   object
#  43  cap                                                                               4969 non-null   object
# dtypes: bool(1), float64(34), object(9)
# memory usage: 1.7+ MB

# %% [markdown]
# ---

# %% [markdown]
# ## Plotting And Interpreting Data

# %%
df['sector'].value_counts()[:60].plot.barh(
    figsize=(20, 15),
    title='Number Of Observation By Sectors'
);

# %%
order = ['large-cap', 'mid-cap', 'small-cap']

# %%
plt.figure(figsize=(20, 15))
sns.countplot(y='cap', data=df, order=order)
plt.title('Number Of Observation By Market Capitalization');

# %% [markdown]
# ---

# %% [markdown]
# ## Correlation Analysis With Target

# %%
float_fs = [f for f in df.columns if df[f].dtypes == 'float64']
nrows = len(float_fs)
fig, ax = plt.subplots(nrows=nrows, ncols=2, figsize=(20, 5 * nrows))
for n, float_f in enumerate(float_fs):
    sns.boxplot(x=float_f, y=target, data=df, order=order, ax=ax[n, 0])
    ax[n, 0].set_title(float_f)
    ax[n, 0].set_xlabel('')
    ax[n, 0].set_xscale('log')
    
    sns.violinplot(x=float_f, y=target, data=df, order=order, ax=ax[n, 1])
    ax[n, 1].set_title(float_f)
    ax[n, 1].set_xlabel('')
    ax[n, 1].set_xscale('log')

# %%
cat_fs = [f for f in df.columns if (df[f].dtypes != 'float64') & (f not in ['security', target, 'sector'])]
nrows = len(cat_fs)
fig, ax = plt.subplots(nrows=nrows, figsize=(20, 5 * nrows))
for n, cat_f in enumerate(cat_fs):
    sns.countplot(y=target, hue=cat_f, data=df, order=order, ax=ax[n])

# %% [markdown]
# ---

# %% [markdown]
# ## Baseline Accuracy

# %% [markdown]
# The baseline accuracy is the percentage of the majority class, regardless of whether it is `large-cap`, `mid-cap` or `small-cap`. It serves as the benchmark for our model to beat.

# %%
df[target].value_counts(normalize=True)
# Out:
# large-cap    0.385993
# small-cap    0.359428
# mid-cap      0.254578
# Name: cap, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Export To `csv` Before Preprocessing

# %%
df.to_csv('../data/to_preprocess.csv', index=False)

# %% [markdown]
# ---

# %%
df[target] = df[target].map({'large-cap': 0, 'mid-cap': 1, 'small-cap': 2})
df['Amendment Flag'] = df['Amendment Flag'].astype(int)
df['Entity Current Reporting Status'] = df['Entity Current Reporting Status'].map({'Yes': 1, 'No': 0})
df['Entity Voluntary Filers'] = df['Entity Voluntary Filers'].map({'Yes': 1, 'No': 0})
df['Entity Well Known Seasoned Issuer'] = df['Entity Well Known Seasoned Issuer'].map({'Yes': 1, 'No': 0})

df = pd.get_dummies(df, columns=[
    'Document Fiscal Period Focus',
    'Document Type',
    'Entity Filer Category',
    'sector'
])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4969 entries, 0 to 4968
# Columns: 172 entries, security to sector_Wireless Telecommunication Services
# dtypes: float64(34), int64(5), object(1), uint8(132)
# memory usage: 2.3+ MB

# %% [markdown]
# ---

# %% [markdown]
# ## Export To `csv` After Preprocessing

# %%
df.to_csv('../data/preprocessed.csv', index=False)
